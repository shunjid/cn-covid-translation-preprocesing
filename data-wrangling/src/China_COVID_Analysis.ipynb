# %% [markdown]
# # Data acquisition
#
# In this section, we will be using pandas to read the dataset in csv file format by using it's function read_csv() and we will be checking some properties of our dataframe.

# %%
import pandas as pd
import numpy as np

# %%
# raw csv file collected from GitHub : @BDBC-KG-NLP/COVID-19-tracker
chinese_province_wise_data = {
    'sichuan'  : 'https://bit.ly/3fOW1BM',
    'anhui'    : 'https://bit.ly/2A7O2Ra',
    'shandong' : 'https://bit.ly/3g1Fo5J',
    'shanxi'   : 'https://bit.ly/3fWyCOJ',
    'jiangsu'  : 'https://bit.ly/2BHdCgk',
    'henan'    : 'https://bit.ly/2BDOhng',
    'zhejiang' : 'https://bit.ly/2NGddNX',
    'hainan'   : 'https://bit.ly/382c7oX',
    'hunan'    : 'https://bit.ly/31cDHyt',
    'guizhou'  : 'https://bit.ly/2Zn6T3l',
    'chongqing': 'https://bit.ly/2YwmvSy'
}

# list of provinces parsing from dict.keys()
provinces = chinese_province_wise_data.keys()

# %%
# list to collect dataframes from each dataset
list_of_frames = []

# iterate and append frame in list_of_frames
for each_province in provinces:
  frame = pd.read_csv(chinese_province_wise_data[each_province], index_col=None, header=None)
  list_of_frames.append(frame)

# df : completely merged frame
df = pd.concat(list_of_frames, axis=0, ignore_index=True)

# %%
# refactoring index bugs
df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
df.drop(df.index[[0]], inplace=True)

# refactor row index
df.reset_index(drop=True, inplace=True)

# custom header
headers = ['Gender', 'Age', 'Work', 'Diagnosis Time', 'Hubei Contact', 'Case Number', 'Permanent Residence', 'Hubei Contact Description', 'Case Announcement Province', 'Case Announcement City', 'Time', 'Route Location', 'Event', 'Description', 'Transportation', 'Track Number', 'Number Of Tracks']

# set custom header to dataframe
df.columns = headers
df.head(3)
# Out:
#   Gender Age Work  ... Transportation Track Number Number Of Tracks
# 0      女  58  NaN  ...            NaN          轨迹1                4
# 1      女  58  NaN  ...            NaN          轨迹2                4
# 2      女  58  NaN  ...            NaN          轨迹3                4
#
# [3 rows x 17 columns]

# %%
# check the shape of 
df.shape
# Out:
# (10790, 17)

# %% [markdown]
# # Data wrangling
#
# In this section, we will be wrangling our data frame for the purpose of converting data from the initial format to a format that may be better for analysis. Sometimes, data-wrangling is referred to as **'data-preprocessing'**. In the beginning of processing, we will be identifying columns needed to be translated from **Chinese to English**.
#
# Before, translating we need to drop some columns that are mostly NaN.

# %%
# find columns NaN percentage
def check_nan() : 
  percent_nan = df.isnull().sum() * 100 / len(df)
  missing_value_in_df = pd.DataFrame(
      {
          'percent_nan': round(percent_nan, 2)
      }
  )
  print(missing_value_in_df)


check_nan()
# Out:
#                             percent_nan
# Gender                             0.00
# Age                                8.02
# Work                              96.60
# Diagnosis Time                    72.91
# Hubei Contact                      0.10
# Case Number                       99.66
# Permanent Residence               18.84
# Hubei Contact Description         85.39
# Case Announcement Province         0.28
# Case Announcement City             0.77
# Time                               0.07
# Route Location                    34.25
# Event                             45.76
# Description                        0.01
# Transportation                    69.94
# Track Number                       0.00
# Number Of Tracks                   0.00

# %% [markdown]
# ### Drop columns
#
# By having an insight over NaN percentage on columns, we can see there are several columns that are mostly NaN. These columns are needed to be removed. But the question is how much NaN should we consider? According to some standard methodologies, columns with more than 50% NaN are useless. So, regarding the standard we will be dropping columns with NaN percentage more than 50%.

# %%
columns_to_drop = ['Work', 'Diagnosis Time', 'Case Number', 'Hubei Contact Description', 'Transportation']

'''
  axis = 1 : for dropping column
  inplace = True : upgrading the dataframe inline
'''
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# find columns NaN percentage
check_nan()
# Out:
#                             percent_nan
# Gender                             0.00
# Age                                8.02
# Hubei Contact                      0.10
# Permanent Residence               18.84
# Case Announcement Province         0.28
# Case Announcement City             0.77
# Time                               0.07
# Route Location                    34.25
# Event                             45.76
# Description                        0.01
# Track Number                       0.00
# Number Of Tracks                   0.00

# %% [markdown]
# ### Drop rows initially
#
# We have so much rows in our dataframe. That's cool unless we think of our translator API performance which we're gonna use next. Translating more than 10K rows in a dataframe might take **10-30 minutes**. Sad, but true 🥺. We cannot define all the important features of our dataset before translation but we can initally detect some of the features that are must for our analysis.
#
# Initially, Age, Permanent Resident, Case Announcement Province, Announcement City and Time are so important feature that must not be NaN. So, we can think of dropping these.

# %%
drop_nan_rows = ['Age', 'Permanent Residence', 'Case Announcement Province', 'Case Announcement City', 'Time', 'Hubei Contact', 'Event']
df.dropna(subset=drop_nan_rows, axis=0, inplace=True)

# reset index, because we droped two rows
df.reset_index(drop=True, inplace=True)

# %%
# find columns NaN percentage
check_nan()
# Out:
#                             percent_nan
# Gender                             0.00
# Age                                0.00
# Hubei Contact                      0.00
# Permanent Residence                0.00
# Case Announcement Province         0.00
# Case Announcement City             0.00
# Time                               0.00
# Route Location                    18.73
# Event                              0.00
# Description                        0.00
# Track Number                       0.00
# Number Of Tracks                   0.00

# %%
df.shape
# Out:
# (4587, 12)

# %% [markdown]
# ### Correcting data type

# %%
df['Age'].unique()
# Out:
# array(['51', '50', '23', '28', '27', '56', '10', '79', '57', '61', '66',
#        '64', '30', '43', '54', '65', '77', '6', '71', '68', '88', '49',
#        '85', '21', '55', '36', '45', '18', '48', '39', '47', '24', '76',
#        '37', '20', '72', '3', '12', '22', '25', '46', '41', '52', '29',
#        '4', '33', '38', '35', '53', '31', '62', '26', '32', '42', '80',
#        '17', '13', '67', '70', '34', '60', '9', '74', '年龄', '63', '40',
#        '58', '44', '16', '11', '69', '59', '75', '90', '73', '14', '78',
#        '15', '84', '89', '1', '5', '19', '8', '7', '91', '2', '86', '82'],
#       dtype=object)

# %%
# Replacing chinese word with average age = 44.75 => 45
df["Age"].replace('年龄', '45', inplace=True)

# %%
df[["Age"]] = df[["Age"]].astype("int")

# %%
df['Number Of Tracks'].max()
# Out:
# '轨迹数量'

# %%
# Initially replace with 0 to find the max
df["Number Of Tracks"].replace('轨迹数量', '0', inplace=True)

# %%
df['Number Of Tracks'].max()
# Out:
# '9'

# %%
df['Number Of Tracks'].unique()
# Out:
# array(['4', '2', '5', '15', '3', '18', '10', '6', '8', '1', '11', '14',
#        '7', '17', '22', '27', '16', '9', '13', '23', '12', '0'],
#       dtype=object)

# %%
df["Number Of Tracks"].replace('0', '9', inplace=True)

# %%
# finally change the type
df[["Number Of Tracks"]] = df[["Number Of Tracks"]].astype("int")

# %%
# check NaN and replace with custom string
# because translation api doesn't take NaN
df['Route Location'].replace(np.nan, '', inplace=True)
check_nan()
# Out:
#                             percent_nan
# Gender                              0.0
# Age                                 0.0
# Hubei Contact                       0.0
# Permanent Residence                 0.0
# Case Announcement Province          0.0
# Case Announcement City              0.0
# Time                                0.0
# Route Location                      0.0
# Event                               0.0
# Description                         0.0
# Track Number                        0.0
# Number Of Tracks                    0.0

# %%
# swap first two columns position for iloc translation
c = df.columns
df[[c[0], c[1]]] = df[[c[1], c[0]]]
df.head(3)
# Out:
#    Gender Age  ... Track Number Number Of Tracks
# 0      51   女  ...          轨迹1                4
# 1      51   女  ...          轨迹2                4
# 2      51   女  ...          轨迹3                4
#
# [3 rows x 12 columns]

# %%
# reset column header
df = df.rename(columns={'Gender': 'Age', 'Age': 'Gender'})
df.head(3)
# Out:
#    Age Gender  ... Track Number Number Of Tracks
# 0   51      女  ...          轨迹1                4
# 1   51      女  ...          轨迹2                4
# 2   51      女  ...          轨迹3                4
#
# [3 rows x 12 columns]

# %%
check_nan()
# Out:
#                             percent_nan
# Age                                 0.0
# Gender                              0.0
# Hubei Contact                       0.0
# Permanent Residence                 0.0
# Case Announcement Province          0.0
# Case Announcement City              0.0
# Time                                0.0
# Route Location                      0.0
# Event                               0.0
# Description                         0.0
# Track Number                        0.0
# Number Of Tracks                    0.0

# %%
df.dtypes
# Out:
# Age                            int64
# Gender                        object
# Hubei Contact                 object
# Permanent Residence           object
# Case Announcement Province    object
# Case Announcement City        object
# Time                          object
# Route Location                object
# Event                         object
# Description                   object
# Track Number                  object
# Number Of Tracks               int64
# dtype: object

# %% [markdown]
# # Data Translation
# In this section, we will be translating our data from Chinese to English. Except Age and Number of track, we need to translate every other columns.

# %%
! pip install googletrans

# %%
# import the library
import googletrans
from googletrans import Translator

# %%
# detect language
translator = Translator()

languages = translator.detect(['石河中心卫生院', 'English', 'বাংলা'])
for lang in languages:
    print(lang.lang, lang.confidence)
# Out:
# zh-CN 1.0
# en 1.0
# bn 1.0

# %%
df.shape
# Out:
# (4587, 12)

# %%
# copy dataframe for translation
df_en = df.copy()
df_en.iloc[:, 1:11].dtypes
# Out:
# Gender                        object
# Hubei Contact                 object
# Permanent Residence           object
# Case Announcement Province    object
# Case Announcement City        object
# Time                          object
# Route Location                object
# Event                         object
# Description                   object
# Track Number                  object
# dtype: object

# %%
# perform translation : skip first and last column
translations = {}
i = 0


for column in df_en.iloc[:, 1:11].columns:
    # unique elements of the column to avoid translating same thing multiple times
    unique_elements = df_en[column].unique()
    print(unique_elements)
    for element in unique_elements:
        # add translation to the dictionary
        translations[element] = translator.translate(element).text
        i = i + 1
        print('t => {}'.format(i))



# debug translation completion
print('Done with translation')
# Out:
# Streaming output truncated to the last 5000 lines.
# t => 3183
# t => 3184
# t => 3185
# t => 3186
# t => 3187
# t => 3188
# t => 3189
# t => 3190
# t => 3191
# t => 3192
# t => 3193
# t => 3194
# t => 3195
# t => 3196
# t => 3197
# t => 3198
# t => 3199
# t => 3200
# t => 3201
# t => 3202
# t => 3203
# t => 3204
# t => 3205
# t => 3206
# t => 3207
# t => 3208
# t => 3209
# t => 3210
# t => 3211
# t => 3212
# t => 3213
# t => 3214
# t => 3215
# t => 3216
# t => 3217
# t => 3218
# t => 3219
# t => 3220
# t => 3221
# t => 3222
# t => 3223
# t => 3224
# t => 3225
# t => 3226
# t => 3227
# t => 3228
# t => 3229
# t => 3230
# t => 3231
# t => 3232
# t => 3233
# t => 3234
# t => 3235
# t => 3236
# t => 3237
# t => 3238
# t => 3239
# t => 3240
# t => 3241
# t => 3242
# t => 3243
# t => 3244
# t => 3245
# t => 3246
# t => 3247
# t => 3248
# t => 3249
# t => 3250
# t => 3251
# t => 3252
# t => 3253
# t => 3254
# t => 3255
# t => 3256
# t => 3257
# t => 3258
# t => 3259
# t => 3260
# t => 3261
# t => 3262
# t => 3263
# t => 3264
# t => 3265
# t => 3266
# t => 3267
# t => 3268
# t => 3269
# t => 3270
# t => 3271
# t => 3272
# t => 3273
# t => 3274
# t => 3275
# t => 3276
# t => 3277
# t => 3278
# t => 3279
# t => 3280
# t => 3281
# t => 3282
# t => 3283
# t => 3284
# t => 3285
# t => 3286
# t => 3287
# t => 3288
# t => 3289
# t => 3290
# t => 3291
# t => 3292
# t => 3293
# t => 3294
# t => 3295
# t => 3296
# t => 3297
# t => 3298
# t => 3299
# t => 3300
# t => 3301
# t => 3302
# t => 3303
# t => 3304
# t => 3305
# t => 3306
# t => 3307
# t => 3308
# t => 3309
# t => 3310
# t => 3311
# t => 3312
# t => 3313
# t => 3314
# t => 3315
# t => 3316
# t => 3317
# t => 3318
# t => 3319
# t => 3320
# t => 3321
# t => 3322
# t => 3323
# t => 3324
# t => 3325
# t => 3326
# t => 3327
# t => 3328
# t => 3329
# t => 3330
# t => 3331
# t => 3332
# t => 3333
# t => 3334
# t => 3335
# t => 3336
# t => 3337
# t => 3338
# t => 3339
# t => 3340
# t => 3341
# t => 3342
# t => 3343
# t => 3344
# t => 3345
# t => 3346
# t => 3347
# t => 3348
# t => 3349
# t => 3350
# t => 3351
# t => 3352
# t => 3353
# t => 3354
# t => 3355
# t => 3356
# t => 3357
# t => 3358
# t => 3359
# t => 3360
# t => 3361
# t => 3362
# t => 3363
# t => 3364
# t => 3365
# t => 3366
# t => 3367
# t => 3368
# t => 3369
# t => 3370
# t => 3371
# t => 3372
# t => 3373
# t => 3374
# t => 3375
# t => 3376
# t => 3377
# t => 3378
# t => 3379
# t => 3380
# t => 3381
# t => 3382
# t => 3383
# t => 3384
# t => 3385
# t => 3386
# t => 3387
# t => 3388
# t => 3389
# t => 3390
# t => 3391
# t => 3392
# t => 3393
# t => 3394
# t => 3395
# t => 3396
# t => 3397
# t => 3398
# t => 3399
# t => 3400
# t => 3401
# t => 3402
# t => 3403
# t => 3404
# t => 3405
# t => 3406
# t => 3407
# t => 3408
# t => 3409
# t => 3410
# t => 3411
# t => 3412
# t => 3413
# t => 3414
# t => 3415
# t => 3416
# t => 3417
# t => 3418
# t => 3419
# t => 3420
# t => 3421
# t => 3422
# t => 3423
# t => 3424
# t => 3425
# t => 3426
# t => 3427
# t => 3428
# t => 3429
# t => 3430
# t => 3431
# t => 3432
# t => 3433
# t => 3434
# t => 3435
# t => 3436
# t => 3437
# t => 3438
# t => 3439
# t => 3440
# t => 3441
# t => 3442
# t => 3443
# t => 3444
# t => 3445
# t => 3446
# t => 3447
# t => 3448
# t => 3449
# t => 3450
# t => 3451
# t => 3452
# t => 3453
# t => 3454
# t => 3455
# t => 3456
# t => 3457
# t => 3458
# t => 3459
# t => 3460
# t => 3461
# t => 3462
# t => 3463
# t => 3464
# t => 3465
# t => 3466
# t => 3467
# t => 3468
# t => 3469
# t => 3470
# t => 3471
# t => 3472
# t => 3473
# t => 3474
# t => 3475
# t => 3476
# t => 3477
# t => 3478
# t => 3479
# t => 3480
# t => 3481
# t => 3482
# t => 3483
# t => 3484
# t => 3485
# t => 3486
# t => 3487
# t => 3488
# t => 3489
# t => 3490
# t => 3491
# t => 3492
# t => 3493
# t => 3494
# t => 3495
# t => 3496
# t => 3497
# t => 3498
# t => 3499
# t => 3500
# t => 3501
# t => 3502
# t => 3503
# t => 3504
# t => 3505
# t => 3506
# t => 3507
# t => 3508
# t => 3509
# t => 3510
# t => 3511
# t => 3512
# t => 3513
# t => 3514
# t => 3515
# t => 3516
# t => 3517
# t => 3518
# t => 3519
# t => 3520
# t => 3521
# t => 3522
# t => 3523
# t => 3524
# t => 3525
# t => 3526
# t => 3527
# t => 3528
# t => 3529
# t => 3530
# t => 3531
# t => 3532
# t => 3533
# t => 3534
# t => 3535
# t => 3536
# t => 3537
# t => 3538
# t => 3539
# t => 3540
# t => 3541
# t => 3542
# t => 3543
# t => 3544
# t => 3545
# t => 3546
# t => 3547
# t => 3548
# t => 3549
# t => 3550
# t => 3551
# t => 3552
# t => 3553
# t => 3554
# t => 3555
# t => 3556
# t => 3557
# t => 3558
# t => 3559
# t => 3560
# t => 3561
# t => 3562
# t => 3563
# t => 3564
# t => 3565
# t => 3566
# t => 3567
# t => 3568
# t => 3569
# t => 3570
# t => 3571
# t => 3572
# t => 3573
# t => 3574
# t => 3575
# t => 3576
# t => 3577
# t => 3578
# t => 3579
# t => 3580
# t => 3581
# t => 3582
# t => 3583
# t => 3584
# t => 3585
# t => 3586
# t => 3587
# t => 3588
# t => 3589
# t => 3590
# t => 3591
# t => 3592
# t => 3593
# t => 3594
# t => 3595
# t => 3596
# t => 3597
# t => 3598
# t => 3599
# t => 3600
# t => 3601
# t => 3602
# t => 3603
# t => 3604
# t => 3605
# t => 3606
# t => 3607
# t => 3608
# t => 3609
# t => 3610
# t => 3611
# t => 3612
# t => 3613
# t => 3614
# t => 3615
# t => 3616
# t => 3617
# t => 3618
# t => 3619
# t => 3620
# t => 3621
# t => 3622
# t => 3623
# t => 3624
# t => 3625
# t => 3626
# t => 3627
# t => 3628
# t => 3629
# t => 3630
# t => 3631
# t => 3632
# t => 3633
# t => 3634
# t => 3635
# t => 3636
# t => 3637
# t => 3638
# t => 3639
# t => 3640
# t => 3641
# t => 3642
# t => 3643
# t => 3644
# t => 3645
# t => 3646
# t => 3647
# t => 3648
# t => 3649
# ['回家' '出现咳嗽等症状' '检查' '收治隔离' '与其他病例密切接触' '出现畏寒症状' '出现咽痛等症状' '就诊' '外出'
#  '在寿尊村' '去本村卫生室' '拜访客户' '发热' '隔离治疗' '选购车辆' '购物' '访友' '闲逛' '逛街' '隔离观察'
#  '解除隔离' '在家' '买菜' '加油' '送小女儿' '送大女儿' '武昌到重庆' '重庆到宜宾' '确诊' '宜昌到西昌' '到达'
#  '采样送检' '北京到成都' '住宿' '成都到西昌' '集中隔离观察点' '入院治疗' '接触成都市一确诊病例' '出现胸闷等症状'
#  '与可疑人员接触' '聚餐' '家属返蓉' '出现干咳症状' '探亲' '返蓉' '离开上海' '到达湖北荆门' '到达巴中' '做客'
#  '湖北到绵竹市' '来蓉' '出现鼻塞等症状' '买药' '开店' '营业' '未外出' '吃饭' '接儿子' '购物、就餐' '接儿子、逛超市'
#  '赶场' '就餐' '就医' '从重庆到罗渡' '上班' '钓鱼' '未知' '团年' '楼下打麻将' '修缮房屋' '安保' '到父母家'
#  '吃饭、回开江县' '回父母家吃饭' '去女友家吃饭' '回开江县' '送亲友' '任市到渠县' '到达安置房' '上坟' '返回安置房'
#  '亲友家吃饭' '到火车站' '渠县到开江' '返回开江县' '取社保卡' '看望病人' '看望病人、吃饭' '马鞍山到南昌' '南昌到湖北'
#  '前往开江' '到达开江县亲友家' '到亲友家吃饭' '返回' '在亲友家休息' '入院隔离治疗' '入住酒店' '其他' '检测结果呈阳性'
#  '隔离收治' '隔离观察并采样' '核酸检测呈阳性' '隔离观擦' '转诊救治' '与武汉返乡人员接触' '去姐夫父亲家' '聚餐、棋牌'
#  '去姐姐家' '去姐夫父亲家中' '将大儿子接回和谐社区' '送大儿子回广兴' '回姐姐家居住' '在姐姐家未外出' '去外婆家'
#  '回外婆家吃饭' '就诊、去伯伯家吃饭' '在村医处就诊' '去姐姐家聚餐' '玩耍居住' '出现发热等症状' '从成都返回道孚'
#  '从汉口到遂宁' '村医处就诊、就餐、打麻将' '针灸' '让村医妻子带药' '村医处就诊' '输液治疗' '吃饭、买验货' '打麻将、量体温'
#  '买菜、买口罩' '打羽毛球' '与武汉返乡者接触' '祭坟并看望母亲' '买菜、在家中举行婚宴' '美发、用餐' '就诊、收治隔离'
#  '参加家庭聚会' '就诊并隔离' '从武汉回开江' '就诊并别隔离' '吃酒' '玩耍' '买蔬菜' '测量体温' '就诊并被隔离'
#  '湖北到德阳' '参加协商家庭事宜' '就诊入院' '厦门飞往长沙' '长沙飞往西昌' '回老家' '买水果、买药' '采购生活必需品'
#  '采购灯具' '到丈母娘家' '宁波到武胜' '参加婚宴' '办事' '就诊并收治隔离' '在家团聚' '楼下买药' '签到' '收治入院'
#  '取钱' '存钱' '买皮鞋' '与武汉来蓉亲属接触' '出现咽痛症状' '出现咳嗽症状' '抵蓉' '出现乏力症状' '旅游' '贵州到南充'
#  '转诊' '在双加镇友谊街' '退衣服' '加气' '接朋友返回南充' '用餐' '去酒吧' '吃饭、取衣服' '送朋友回老家' '买口罩'
#  '去父母家就餐' '买药、接朋友' '买药、送朋友回家' '去父母家用餐' '汉口到重庆' '到岳父家' '回父母家' '在父母家与大哥接触'
#  '接大舅' '到二舅加吃饭' '在父母家' '去堂兄家吃饭' '输液' '返回重庆' '出现腹泻症状' '回湖北老家' '集中隔离'
#  '出现发热症状' '探亲后返回' '出现干咳等症状' '从南充抵蓉' '出现头晕症状' '与武汉来蓉人员接触' '与湖北来蓉人员接触'
#  '采样送检并入院治疗' '武汉到南充' '武汉到渠县' '理发' '在家招待客人' '采样送检并隔离治疗' '丽江到四川' '武汉到成都'
#  '到达甘洛' '到达家中' '因外伤昏迷送至医院' '到家' '到达西昌' '到达父母家' '在父母家聚餐' '宜昌到重庆' '重庆到成都'
#  '入住小区' '到亲家家' '接家属' '入住宾馆' '爬泸山' '换乘' '回宾馆' '退房' '去亲家家' '在亲家家' '看病' '去坐车'
#  '接男友' '去男友家' '就诊并收治入院' '就诊并隔离治疗' '值班' '居家观察' '送人' '工作' '接女儿' '逛超市'
#  '看望母亲和哥哥' '购物一次' '参加婚礼' '聚会' '停留' '乘车' '打牌' '聚餐·' '参加年会' '打麻将' '租房'
#  '住了一晚' '事件' '治疗' '隔离' '采样' '送水' '散步' '呆家' '发病' '出行' '返蚌' '腹泻' '服药' '居家'
#  '住院' '标本送检' '酒店住宿' '采样检查' '咳嗽' '返乡过年' '返乡' '救火' '单位值班' '返家' '购药' '干咳'
#  '患者接触' '浴场消费' '聊天' '病患接触' '感冒' '头痛' '婚车服务' '接亲' '看楼盘' '吃早餐' '新建村夏家庄' '逗留'
#  '转车' '出现发烧' '参加展销会并' '回乡' '拜年' '筛查' '返回泰安市岱岳区' '走亲' '维修燃气灶和购物'
#  '去医院给母亲送饭，接母亲出院' '去哥哥家' '拜年和购物' '陪母亲去医院' '先取物，后去医院' '买酒精' '初筛检测' '疑似检测'
#  '出现发热症状，入院治疗' '与疑似病例有密切接触' '与可疑病例有密切接触' '巡查' '乘坐火车返乡' '检测确诊' '看望家属'
#  '因血液病就诊' '发热、咳嗽' '入住医院脑康复科病房治疗' '转院治疗' '退热，但仍有咳嗽' '入住医院康复科治疗' '照料' '开始咳嗽'
#  '离开武汉到莱芜停留1天' '发热隔离' '解除医学观察' '陪同其儿子输液' '给婆婆送饭' '到小区门口送东西' '串门' '疑似采样并确诊'
#  '从武汉返乡' '疑似检测并确诊' '居家活动' '参加公司年会' '自驾' '在家并出现发热情况' '在家并出现干咳症状' '接客人'
#  '送母亲' '去岳母家' '接母亲' '接妻儿' '确诊并隔离' '置办年货' '在同村村民家进行建筑活动' '单位聚餐' '与父母就餐'
#  '居家隔离' '与武汉、湖北人员有过密切接触' '出现脚凉症状' '陪护家属' '与武汉返泰人员有过接触' '与李某荣接触' '在小区内活动'
#  '购书' '购买耳机' '小区内活动' '居家隔离观察' '因发热，入院观察治疗' '与武汉返泰人员有接触' '出现发烧症状' '入院隔离并确诊'
#  '从武汉到信阳' '到达火车站' '乘坐高铁' '到达机场' '到达蓬莱' '理发、买水果' '陪儿子看眼' '带儿子看病' '贴福字、赶集'
#  '从武汉回到烟台' '烟台到牟平' '从武汉到青岛' '从武汉到莱州' '出差' '返青' '就诊、工作' '治愈' '陪家人就诊' '生活工作'
#  '居住' '游玩' '转院' '锻炼，购买生活必需品' '转送' '集中隔离医学观察' '跑步' '打针' '就诊留观' '照顾岳父'
#  '返回平遥家中' '吃饭停留半小时' '乘坐849路公交车' '住宿一晚' '购买口罩，理发' '活动' '从事拉客营运' '回河津' '吊唁'
#  '集会' '看望亲戚' '购物广场' '购物，就餐' '干活' '报表' '探望岳父母' '探望姐姐' '进行舞蹈排练' '进行演出'
#  '通宵上网' '开会' '入住' '去医院' '去火车站' '洗浴' '送医' '去武汉' '卸货' '身体不适' '开船' '旅行' '坐飞机'
#  '在亲戚家' '去上海' '去滨海' '1月20日,乘D1693 从连云港 到滨海县' '去盐城' '回海门' '去吊唁' '在家聚餐'
#  '去苏州' '硕放机场' '发烧' '采购' '拜访亲戚' '取药' '包场' '医院陪护' '去机场' '乘高铁' '去珠海' '去澳门'
#  '肌肉酸痛' '去深圳' '回珠海' '入院' ' 确诊' '低热' '去襄阳' '乏力' '接回苏亲属' '见客户' '医院观察' '去湖北'
#  '接触咳嗽症状人士' '医学观察' '武汉回苏亲属' '去蚌埠' '办理业务' '接触武汉人员' '卖东西' '回湖北' '出国旅游' '回苏州'
#  '出现症状' '集中观察' '下车' '在酒店' '买药和口罩' '售卖水产' '打球' '与患者同住' '打工' '常住武汉' '发热输液'
#  '出现不适' '集中隔离点' '参加女儿的婚礼' '参加外孙女的婚礼' '没有' '探亲时' '隆胜华庭小区' '赶集' '开车' '经商'
#  '夜宿' '开' '洗澡' '看电影' '回到夏邑县家中' '看望母亲' '转乘' '先行下车' '看望干妈' '停留就餐' '吃喜宴'
#  '参加会议' '参加亲戚婚宴' '务工' '参加培训' '回' '参加祈福活动' '看牙' '回杭' '返回乐清' '出现' '不适' '去酒店'
#  '从武汉前往海南' '未出门' '到海口' '住酒店' '离开武汉' '前往海南' '死亡' '抵达海南' '抵达海口' '去泰国' '抵达三亚'
#  '从武汉出发' '抵达镇江' '抵达海安' '坐船' '离开深圳' '前往琼海' '购买船票' '前往三亚' '进入海南' '照顾病患'
#  '接待武汉亲戚' '在武汉' '与病患接触' '开车拉客' '检测阳性' '检测阴性' '在家隔离' '前往海口' '去海南' '观光'
#  '居家散步' '下去入住' '附近菜市场买菜' '家中聚餐' '小区附近活动' '度假' '在酒店未外出' '到小区' '游玩6天' '出院'
#  '接90号病例' '过年' '办理入住' '乘' '办理入住,用餐' '回三亚' '宿舍休息' '飞往三亚' '购物并回玉良村老家' '看房'
#  '去朋友家' '在朋友家' '复诊' '回老家过年' '附近买菜' '买菜后购物' '卫生院就诊' '交费' '附近购物' '到朋友家用餐'
#  '酒店入住' '小区附近买菜' '附近超市购物' '医学隔离' '上下班' '接12号病例' '看望亲属' '送早餐' '看村民排球比赛'
#  '在老家' '陪护亲属' '取快递' '隔离解除' '用午餐' '在住处' '逛街1天' '赴宴' '育才路北站社区卫生服务站' '返回贵阳家中'
#  '泗渡居胜利组外祖父家中' '泗渡居胜利组女友' '军阅酒店' '转乘火车' '泗渡居老家' '集中隔离点观察' '铺车站'
#  '办凤朝门社区父母家中' '指定场所' '停留了20分钟' '接回' '下车回家' '返乡人员' '登山' '参加酒宴' '并入住瀑福缘酒店'
#  '居住3天' '集中医学' '接' '抵达救民村家中' '祭祀' '卖肉' '在侄女陈某家休息' '去医院照顾其父' '出现咽喉不适'
#  '去其妹妹家' '去侄女陈某家' '买药回家' '参加葬礼' '看望父亲' '感觉不适' '全家聚餐' '乘K356次列车' '参加宴会'
#  '返万人员' '拜访' '排查、采样' '与妻子就诊' '从武汉会重庆' '遇东岚餐厅参加聚会' '在家出现不适' '转院就诊' '自驾离开湖北'
#  '离开湖北' '去成都' '回重庆' '参加灯会' '再次就诊' '暂住的恒兴酒店房间' '到机场' '乘坐D623次动车08车厢' '讲课'
#  '乘坐出租车' '取肉' '烧香' '自驾到綦江' '外公家就餐' '自驾从武汉到綦江' '出发到綦江' '外出后回家' '乘坐自驾' '去西安'
#  '去四川' '返回城口县沿河乡家中' '医院探亲' '就诊排查' '确诊隔离' '请医生就诊' '公司聚餐' '往返医院照顾病人'
#  '在家出现症状' '就餐购物' '去长寿区' '回到大足区' '在家请客' '接人' '做生意' '进货' '处理家务' '放假回家'
#  '参加外孙百日宴' '上坟后吃饭' '就诊后回家' '住院治疗' '家庭团年' '回万州' '程耀诊所' '诊所治疗' '在家打牌' '徒步就诊'
#  '去三峡医院就诊' '去开会' '会议结束' '步行' '坐客车' '返万' '乘坐朋友' '进行居家隔离' '巫山服务站短暂' '探亲聚餐'
#  '割裂' '体检' '乘坐轻轨1号线' '会龙高石村14组亲戚家' '购买年货' '出发' '病倒' '集中治疗' '出站' '吃晚饭'
#  '搭乘客车' '婚庆' '开家长会' '参加侄女婚宴' '转乘中巴车' '接岳父出院' '就诊隔离' '胜百汇超市' '登高' '参加聚餐'
#  '丧礼宴席' '返万人员聚餐' '隔离排查' '做家政3小时' '排查' '蓉' '旅游大道' '旅游大道草坪' '看望同学' '遇东岚餐厅'
#  '嘉乐汇购物公园' '乘坐轻轨10号线' '去云南' '确诊病例' '旭辉城星巴克店' '批发市场' '坐夜演出' '演出' '婚宴'
#  '在家团员' '参加丧礼' '回分水镇' '就诊确诊' '在家门口聊天' '从温州回万' '在家出现腹泻' '去当地诊所治疗' '在儿子家'
#  '到岳母家吃饭' '游玩吃饭' '去妹妹家' '祭祖' '儿童医院就诊' '出差回来' '小区附近就诊' '在G8508上工作'
#  '在G8541上工作' '出现疑似症状' '返回泸州']
# t => 3650
# t => 3651
# t => 3652
# t => 3653
# t => 3654
# t => 3655
# t => 3656
# t => 3657
# t => 3658
# t => 3659
# t => 3660
# t => 3661
# t => 3662
# t => 3663
# t => 3664
# t => 3665
# t => 3666
# t => 3667
# t => 3668
# t => 3669
# t => 3670
# t => 3671
# t => 3672
# t => 3673
# t => 3674
# t => 3675
# t => 3676
# t => 3677
# t => 3678
# t => 3679
# t => 3680
# t => 3681
# t => 3682
# t => 3683
# t => 3684
# t => 3685
# t => 3686
# t => 3687
# t => 3688
# t => 3689
# t => 3690
# t => 3691
# t => 3692
# t => 3693
# t => 3694
# t => 3695
# t => 3696
# t => 3697
# t => 3698
# t => 3699
# t => 3700
# t => 3701
# t => 3702
# t => 3703
# t => 3704
# t => 3705
# t => 3706
# t => 3707
# t => 3708
# t => 3709
# t => 3710
# t => 3711
# t => 3712
# t => 3713
# t => 3714
# t => 3715
# t => 3716
# t => 3717
# t => 3718
# t => 3719
# t => 3720
# t => 3721
# t => 3722
# t => 3723
# t => 3724
# t => 3725
# t => 3726
# t => 3727
# t => 3728
# t => 3729
# t => 3730
# t => 3731
# t => 3732
# t => 3733
# t => 3734
# t => 3735
# t => 3736
# t => 3737
# t => 3738
# t => 3739
# t => 3740
# t => 3741
# t => 3742
# t => 3743
# t => 3744
# t => 3745
# t => 3746
# t => 3747
# t => 3748
# t => 3749
# t => 3750
# t => 3751
# t => 3752
# t => 3753
# t => 3754
# t => 3755
# t => 3756
# t => 3757
# t => 3758
# t => 3759
# t => 3760
# t => 3761
# t => 3762
# t => 3763
# t => 3764
# t => 3765
# t => 3766
# t => 3767
# t => 3768
# t => 3769
# t => 3770
# t => 3771
# t => 3772
# t => 3773
# t => 3774
# t => 3775
# t => 3776
# t => 3777
# t => 3778
# t => 3779
# t => 3780
# t => 3781
# t => 3782
# t => 3783
# t => 3784
# t => 3785
# t => 3786
# t => 3787
# t => 3788
# t => 3789
# t => 3790
# t => 3791
# t => 3792
# t => 3793
# t => 3794
# t => 3795
# t => 3796
# t => 3797
# t => 3798
# t => 3799
# t => 3800
# t => 3801
# t => 3802
# t => 3803
# t => 3804
# t => 3805
# t => 3806
# t => 3807
# t => 3808
# t => 3809
# t => 3810
# t => 3811
# t => 3812
# t => 3813
# t => 3814
# t => 3815
# t => 3816
# t => 3817
# t => 3818
# t => 3819
# t => 3820
# t => 3821
# t => 3822
# t => 3823
# t => 3824
# t => 3825
# t => 3826
# t => 3827
# t => 3828
# t => 3829
# t => 3830
# t => 3831
# t => 3832
# t => 3833
# t => 3834
# t => 3835
# t => 3836
# t => 3837
# t => 3838
# t => 3839
# t => 3840
# t => 3841
# t => 3842
# t => 3843
# t => 3844
# t => 3845
# t => 3846
# t => 3847
# t => 3848
# t => 3849
# t => 3850
# t => 3851
# t => 3852
# t => 3853
# t => 3854
# t => 3855
# t => 3856
# t => 3857
# t => 3858
# t => 3859
# t => 3860
# t => 3861
# t => 3862
# t => 3863
# t => 3864
# t => 3865
# t => 3866
# t => 3867
# t => 3868
# t => 3869
# t => 3870
# t => 3871
# t => 3872
# t => 3873
# t => 3874
# t => 3875
# t => 3876
# t => 3877
# t => 3878
# t => 3879
# t => 3880
# t => 3881
# t => 3882
# t => 3883
# t => 3884
# t => 3885
# t => 3886
# t => 3887
# t => 3888
# t => 3889
# t => 3890
# t => 3891
# t => 3892
# t => 3893
# t => 3894
# t => 3895
# t => 3896
# t => 3897
# t => 3898
# t => 3899
# t => 3900
# t => 3901
# t => 3902
# t => 3903
# t => 3904
# t => 3905
# t => 3906
# t => 3907
# t => 3908
# t => 3909
# t => 3910
# t => 3911
# t => 3912
# t => 3913
# t => 3914
# t => 3915
# t => 3916
# t => 3917
# t => 3918
# t => 3919
# t => 3920
# t => 3921
# t => 3922
# t => 3923
# t => 3924
# t => 3925
# t => 3926
# t => 3927
# t => 3928
# t => 3929
# t => 3930
# t => 3931
# t => 3932
# t => 3933
# t => 3934
# t => 3935
# t => 3936
# t => 3937
# t => 3938
# t => 3939
# t => 3940
# t => 3941
# t => 3942
# t => 3943
# t => 3944
# t => 3945
# t => 3946
# t => 3947
# t => 3948
# t => 3949
# t => 3950
# t => 3951
# t => 3952
# t => 3953
# t => 3954
# t => 3955
# t => 3956
# t => 3957
# t => 3958
# t => 3959
# t => 3960
# t => 3961
# t => 3962
# t => 3963
# t => 3964
# t => 3965
# t => 3966
# t => 3967
# t => 3968
# t => 3969
# t => 3970
# t => 3971
# t => 3972
# t => 3973
# t => 3974
# t => 3975
# t => 3976
# t => 3977
# t => 3978
# t => 3979
# t => 3980
# t => 3981
# t => 3982
# t => 3983
# t => 3984
# t => 3985
# t => 3986
# t => 3987
# t => 3988
# t => 3989
# t => 3990
# t => 3991
# t => 3992
# t => 3993
# t => 3994
# t => 3995
# t => 3996
# t => 3997
# t => 3998
# t => 3999
# t => 4000
# t => 4001
# t => 4002
# t => 4003
# t => 4004
# t => 4005
# t => 4006
# t => 4007
# t => 4008
# t => 4009
# t => 4010
# t => 4011
# t => 4012
# t => 4013
# t => 4014
# t => 4015
# t => 4016
# t => 4017
# t => 4018
# t => 4019
# t => 4020
# t => 4021
# t => 4022
# t => 4023
# t => 4024
# t => 4025
# t => 4026
# t => 4027
# t => 4028
# t => 4029
# t => 4030
# t => 4031
# t => 4032
# t => 4033
# t => 4034
# t => 4035
# t => 4036
# t => 4037
# t => 4038
# t => 4039
# t => 4040
# t => 4041
# t => 4042
# t => 4043
# t => 4044
# t => 4045
# t => 4046
# t => 4047
# t => 4048
# t => 4049
# t => 4050
# t => 4051
# t => 4052
# t => 4053
# t => 4054
# t => 4055
# t => 4056
# t => 4057
# t => 4058
# t => 4059
# t => 4060
# t => 4061
# t => 4062
# t => 4063
# t => 4064
# t => 4065
# t => 4066
# t => 4067
# t => 4068
# t => 4069
# t => 4070
# t => 4071
# t => 4072
# t => 4073
# t => 4074
# t => 4075
# t => 4076
# t => 4077
# t => 4078
# t => 4079
# t => 4080
# t => 4081
# t => 4082
# t => 4083
# t => 4084
# t => 4085
# t => 4086
# t => 4087
# t => 4088
# t => 4089
# t => 4090
# t => 4091
# t => 4092
# t => 4093
# t => 4094
# t => 4095
# t => 4096
# t => 4097
# t => 4098
# t => 4099
# t => 4100
# t => 4101
# t => 4102
# t => 4103
# t => 4104
# t => 4105
# t => 4106
# t => 4107
# t => 4108
# t => 4109
# t => 4110
# t => 4111
# t => 4112
# t => 4113
# t => 4114
# t => 4115
# t => 4116
# t => 4117
# t => 4118
# t => 4119
# t => 4120
# t => 4121
# t => 4122
# t => 4123
# t => 4124
# t => 4125
# t => 4126
# t => 4127
# t => 4128
# t => 4129
# t => 4130
# t => 4131
# t => 4132
# t => 4133
# t => 4134
# t => 4135
# t => 4136
# t => 4137
# t => 4138
# t => 4139
# t => 4140
# t => 4141
# t => 4142
# t => 4143
# t => 4144
# t => 4145
# t => 4146
# t => 4147
# t => 4148
# t => 4149
# t => 4150
# t => 4151
# t => 4152
# t => 4153
# t => 4154
# t => 4155
# t => 4156
# t => 4157
# t => 4158
# t => 4159
# t => 4160
# t => 4161
# t => 4162
# t => 4163
# t => 4164
# t => 4165
# t => 4166
# t => 4167
# t => 4168
# t => 4169
# t => 4170
# t => 4171
# t => 4172
# t => 4173
# t => 4174
# t => 4175
# t => 4176
# t => 4177
# t => 4178
# t => 4179
# t => 4180
# t => 4181
# t => 4182
# t => 4183
# t => 4184
# t => 4185
# t => 4186
# t => 4187
# t => 4188
# t => 4189
# t => 4190
# t => 4191
# t => 4192
# t => 4193
# t => 4194
# t => 4195
# t => 4196
# t => 4197
# t => 4198
# t => 4199
# t => 4200
# t => 4201
# t => 4202
# t => 4203
# t => 4204
# t => 4205
# t => 4206
# t => 4207
# t => 4208
# t => 4209
# t => 4210
# t => 4211
# t => 4212
# t => 4213
# t => 4214
# t => 4215
# t => 4216
# t => 4217
# t => 4218
# t => 4219
# t => 4220
# t => 4221
# t => 4222
# t => 4223
# t => 4224
# t => 4225
# t => 4226
# t => 4227
# t => 4228
# t => 4229
# t => 4230
# t => 4231
# t => 4232
# t => 4233
# t => 4234
# t => 4235
# t => 4236
# t => 4237
# t => 4238
# t => 4239
# t => 4240
# t => 4241
# t => 4242
# t => 4243
# t => 4244
# t => 4245
# t => 4246
# t => 4247
# t => 4248
# t => 4249
# t => 4250
# t => 4251
# t => 4252
# t => 4253
# t => 4254
# t => 4255
# t => 4256
# t => 4257
# t => 4258
# t => 4259
# t => 4260
# t => 4261
# t => 4262
# t => 4263
# t => 4264
# t => 4265
# t => 4266
# t => 4267
# t => 4268
# t => 4269
# t => 4270
# t => 4271
# t => 4272
# t => 4273
# t => 4274
# t => 4275
# t => 4276
# t => 4277
# t => 4278
# t => 4279
# t => 4280
# t => 4281
# t => 4282
# t => 4283
# t => 4284
# t => 4285
# t => 4286
# t => 4287
# t => 4288
# t => 4289
# t => 4290
# t => 4291
# t => 4292
# t => 4293
# t => 4294
# t => 4295
# t => 4296
# t => 4297
# t => 4298
# t => 4299
# t => 4300
# t => 4301
# t => 4302
# t => 4303
# t => 4304
# t => 4305
# t => 4306
# t => 4307
# t => 4308
# t => 4309
# t => 4310
# t => 4311
# t => 4312
# t => 4313
# t => 4314
# t => 4315
# t => 4316
# t => 4317
# t => 4318
# t => 4319
# t => 4320
# t => 4321
# t => 4322
# t => 4323
# t => 4324
# t => 4325
# t => 4326
# t => 4327
# t => 4328
# t => 4329
# t => 4330
# t => 4331
# t => 4332
# t => 4333
# t => 4334
# t => 4335
# t => 4336
# t => 4337
# t => 4338
# t => 4339
# t => 4340
# t => 4341
# t => 4342
# t => 4343
# t => 4344
# t => 4345
# t => 4346
# t => 4347
# t => 4348
# t => 4349
# t => 4350
# t => 4351
# t => 4352
# t => 4353
# t => 4354
# t => 4355
# t => 4356
# t => 4357
# t => 4358
# t => 4359
# t => 4360
# t => 4361
# t => 4362
# t => 4363
# t => 4364
# t => 4365
# t => 4366
# t => 4367
# t => 4368
# t => 4369
# t => 4370
# t => 4371
# t => 4372
# t => 4373
# t => 4374
# t => 4375
# t => 4376
# t => 4377
# t => 4378
# t => 4379
# t => 4380
# t => 4381
# t => 4382
# t => 4383
# t => 4384
# t => 4385
# t => 4386
# t => 4387
# t => 4388
# t => 4389
# t => 4390
# t => 4391
# t => 4392
# t => 4393
# t => 4394
# t => 4395
# t => 4396
# t => 4397
# t => 4398
# t => 4399
# t => 4400
# t => 4401
# t => 4402
# ['1月19日, 雷某英独自从武汉返回泸县牛滩镇寿尊村10社家中' '1月23日, 出现咳嗽、头痛等症状，自行服药后缓解'
#  '1月24日, 到牛滩镇卫生院检查未见异常（未如实提供武汉返泸史）' ... '1月26日, 出现发热、头痛等不适症状'
#  '1月30日, 乘坐出租车（具体车牌记不清）前往渝北区第二人民医院就诊，后该院用专用车辆将其转运至渝北区人民医院并被确诊。'
#  '1月29日, 出现发热症状，由回兴社区卫生服务中心用专用车将其送往重庆医科大学附属第三医院诊治']
# t => 4403
# t => 4404
# t => 4405
# t => 4406
# t => 4407
# t => 4408
# t => 4409
# t => 4410
# t => 4411
# t => 4412
# t => 4413
# t => 4414
# t => 4415
# t => 4416
# t => 4417
# t => 4418
# t => 4419
# t => 4420
# t => 4421
# t => 4422
# t => 4423
# t => 4424
# t => 4425
# t => 4426
# t => 4427
# t => 4428
# t => 4429
# t => 4430
# t => 4431
# t => 4432
# t => 4433
# t => 4434
# t => 4435
# t => 4436
# t => 4437
# t => 4438
# t => 4439
# t => 4440
# t => 4441
# t => 4442
# t => 4443
# t => 4444
# t => 4445
# t => 4446
# t => 4447
# t => 4448
# t => 4449
# t => 4450
# t => 4451
# t => 4452
# t => 4453
# t => 4454
# t => 4455
# t => 4456
# t => 4457
# t => 4458
# t => 4459
# t => 4460
# t => 4461
# t => 4462
# t => 4463
# t => 4464
# t => 4465
# t => 4466
# t => 4467
# t => 4468
# t => 4469
# t => 4470
# t => 4471
# t => 4472
# t => 4473
# t => 4474
# t => 4475
# t => 4476
# t => 4477
# t => 4478
# t => 4479
# t => 4480
# t => 4481
# t => 4482
# t => 4483
# t => 4484
# t => 4485
# t => 4486
# t => 4487
# t => 4488
# t => 4489
# t => 4490
# t => 4491
# t => 4492
# t => 4493
# t => 4494
# t => 4495
# t => 4496
# t => 4497
# t => 4498
# t => 4499
# t => 4500
# t => 4501
# t => 4502
# t => 4503
# t => 4504
# t => 4505
# t => 4506
# t => 4507
# t => 4508
# t => 4509
# t => 4510
# t => 4511
# t => 4512
# t => 4513
# t => 4514
# t => 4515
# t => 4516
# t => 4517
# t => 4518
# t => 4519
# t => 4520
# t => 4521
# t => 4522
# t => 4523
# t => 4524
# t => 4525
# t => 4526
# t => 4527
# t => 4528
# t => 4529
# t => 4530
# t => 4531
# t => 4532
# t => 4533
# t => 4534
# t => 4535
# t => 4536
# t => 4537
# t => 4538
# t => 4539
# t => 4540
# t => 4541
# t => 4542
# t => 4543
# t => 4544
# t => 4545
# t => 4546
# t => 4547
# t => 4548
# t => 4549
# t => 4550
# t => 4551
# t => 4552
# t => 4553
# t => 4554
# t => 4555
# t => 4556
# t => 4557
# t => 4558
# t => 4559
# t => 4560
# t => 4561
# t => 4562
# t => 4563
# t => 4564
# t => 4565
# t => 4566
# t => 4567
# t => 4568
# t => 4569
# t => 4570
# t => 4571
# t => 4572
# t => 4573
# t => 4574
# t => 4575
# t => 4576
# t => 4577
# t => 4578
# t => 4579
# t => 4580
# t => 4581
# t => 4582
# t => 4583
# t => 4584
# t => 4585
# t => 4586
# t => 4587
# t => 4588
# t => 4589
# t => 4590
# t => 4591
# t => 4592
# t => 4593
# t => 4594
# t => 4595
# t => 4596
# t => 4597
# t => 4598
# t => 4599
# t => 4600
# t => 4601
# t => 4602
# t => 4603
# t => 4604
# t => 4605
# t => 4606
# t => 4607
# t => 4608
# t => 4609
# t => 4610
# t => 4611
# t => 4612
# t => 4613
# t => 4614
# t => 4615
# t => 4616
# t => 4617
# t => 4618
# t => 4619
# t => 4620
# t => 4621
# t => 4622
# t => 4623
# t => 4624
# t => 4625
# t => 4626
# t => 4627
# t => 4628
# t => 4629
# t => 4630
# t => 4631
# t => 4632
# t => 4633
# t => 4634
# t => 4635
# t => 4636
# t => 4637
# t => 4638
# t => 4639
# t => 4640
# t => 4641
# t => 4642
# t => 4643
# t => 4644
# t => 4645
# t => 4646
# t => 4647
# t => 4648
# t => 4649
# t => 4650
# t => 4651
# t => 4652
# t => 4653
# t => 4654
# t => 4655
# t => 4656
# t => 4657
# t => 4658
# t => 4659
# t => 4660
# t => 4661
# t => 4662
# t => 4663
# t => 4664
# t => 4665
# t => 4666
# t => 4667
# t => 4668
# t => 4669
# t => 4670
# t => 4671
# t => 4672
# t => 4673
# t => 4674
# t => 4675
# t => 4676
# t => 4677
# t => 4678
# t => 4679
# t => 4680
# t => 4681
# t => 4682
# t => 4683
# t => 4684
# t => 4685
# t => 4686
# t => 4687
# t => 4688
# t => 4689
# t => 4690
# t => 4691
# t => 4692
# t => 4693
# t => 4694
# t => 4695
# t => 4696
# t => 4697
# t => 4698
# t => 4699
# t => 4700
# t => 4701
# t => 4702
# t => 4703
# t => 4704
# t => 4705
# t => 4706
# t => 4707
# t => 4708
# t => 4709
# t => 4710
# t => 4711
# t => 4712
# t => 4713
# t => 4714
# t => 4715
# t => 4716
# t => 4717
# t => 4718
# t => 4719
# t => 4720
# t => 4721
# t => 4722
# t => 4723
# t => 4724
# t => 4725
# t => 4726
# t => 4727
# t => 4728
# t => 4729
# t => 4730
# t => 4731
# t => 4732
# t => 4733
# t => 4734
# t => 4735
# t => 4736
# t => 4737
# t => 4738
# t => 4739
# t => 4740
# t => 4741
# t => 4742
# t => 4743
# t => 4744
# t => 4745
# t => 4746
# t => 4747
# t => 4748
# t => 4749
# t => 4750
# t => 4751
# t => 4752
# t => 4753
# t => 4754
# t => 4755
# t => 4756
# t => 4757
# t => 4758
# t => 4759
# t => 4760
# t => 4761
# t => 4762
# t => 4763
# t => 4764
# t => 4765
# t => 4766
# t => 4767
# t => 4768
# t => 4769
# t => 4770
# t => 4771
# t => 4772
# t => 4773
# t => 4774
# t => 4775
# t => 4776
# t => 4777
# t => 4778
# t => 4779
# t => 4780
# t => 4781
# t => 4782
# t => 4783
# t => 4784
# t => 4785
# t => 4786
# t => 4787
# t => 4788
# t => 4789
# t => 4790
# t => 4791
# t => 4792
# t => 4793
# t => 4794
# t => 4795
# t => 4796
# t => 4797
# t => 4798
# t => 4799
# t => 4800
# t => 4801
# t => 4802
# t => 4803
# t => 4804
# t => 4805
# t => 4806
# t => 4807
# t => 4808
# t => 4809
# t => 4810
# t => 4811
# t => 4812
# t => 4813
# t => 4814
# t => 4815
# t => 4816
# t => 4817
# t => 4818
# t => 4819
# t => 4820
# t => 4821
# t => 4822
# t => 4823
# t => 4824
# t => 4825
# t => 4826
# t => 4827
# t => 4828
# t => 4829
# t => 4830
# t => 4831
# t => 4832
# t => 4833
# t => 4834
# t => 4835
# t => 4836
# t => 4837
# t => 4838
# t => 4839
# t => 4840
# t => 4841
# t => 4842
# t => 4843
# t => 4844
# t => 4845
# t => 4846
# t => 4847
# t => 4848
# t => 4849
# t => 4850
# t => 4851
# t => 4852
# t => 4853
# t => 4854
# t => 4855
# t => 4856
# t => 4857
# t => 4858
# t => 4859
# t => 4860
# t => 4861
# t => 4862
# t => 4863
# t => 4864
# t => 4865
# t => 4866
# t => 4867
# t => 4868
# t => 4869
# t => 4870
# t => 4871
# t => 4872
# t => 4873
# t => 4874
# t => 4875
# t => 4876
# t => 4877
# t => 4878
# t => 4879
# t => 4880
# t => 4881
# t => 4882
# t => 4883
# t => 4884
# t => 4885
# t => 4886
# t => 4887
# t => 4888
# t => 4889
# t => 4890
# t => 4891
# t => 4892
# t => 4893
# t => 4894
# t => 4895
# t => 4896
# t => 4897
# t => 4898
# t => 4899
# t => 4900
# t => 4901
# t => 4902
# t => 4903
# t => 4904
# t => 4905
# t => 4906
# t => 4907
# t => 4908
# t => 4909
# t => 4910
# t => 4911
# t => 4912
# t => 4913
# t => 4914
# t => 4915
# t => 4916
# t => 4917
# t => 4918
# t => 4919
# t => 4920
# t => 4921
# t => 4922
# t => 4923
# t => 4924
# t => 4925
# t => 4926
# t => 4927
# t => 4928
# t => 4929
# t => 4930
# t => 4931
# t => 4932
# t => 4933
# t => 4934
# t => 4935
# t => 4936
# t => 4937
# t => 4938
# t => 4939
# t => 4940
# t => 4941
# t => 4942
# t => 4943
# t => 4944
# t => 4945
# t => 4946
# t => 4947
# t => 4948
# t => 4949
# t => 4950
# t => 4951
# t => 4952
# t => 4953
# t => 4954
# t => 4955
# t => 4956
# t => 4957
# t => 4958
# t => 4959
# t => 4960
# t => 4961
# t => 4962
# t => 4963
# t => 4964
# t => 4965
# t => 4966
# t => 4967
# t => 4968
# t => 4969
# t => 4970
# t => 4971
# t => 4972
# t => 4973
# t => 4974
# t => 4975
# t => 4976
# t => 4977
# t => 4978
# t => 4979
# t => 4980
# t => 4981
# t => 4982
# t => 4983
# t => 4984
# t => 4985
# t => 4986
# t => 4987
# t => 4988
# t => 4989
# t => 4990
# t => 4991
# t => 4992
# t => 4993
# t => 4994
# t => 4995
# t => 4996
# t => 4997
# t => 4998
# t => 4999
# t => 5000
# t => 5001
# t => 5002
# t => 5003
# t => 5004
# t => 5005
# t => 5006
# t => 5007
# t => 5008
# t => 5009
# t => 5010
# t => 5011
# t => 5012
# t => 5013
# t => 5014
# t => 5015
# t => 5016
# t => 5017
# t => 5018
# t => 5019
# t => 5020
# t => 5021
# t => 5022
# t => 5023
# t => 5024
# t => 5025
# t => 5026
# t => 5027
# t => 5028
# t => 5029
# t => 5030
# t => 5031
# t => 5032
# t => 5033
# t => 5034
# t => 5035
# t => 5036
# t => 5037
# t => 5038
# t => 5039
# t => 5040
# t => 5041
# t => 5042
# t => 5043
# t => 5044
# t => 5045
# t => 5046
# t => 5047
# t => 5048
# t => 5049
# t => 5050
# t => 5051
# t => 5052
# t => 5053
# t => 5054
# t => 5055
# t => 5056
# t => 5057
# t => 5058
# t => 5059
# t => 5060
# t => 5061
# t => 5062
# t => 5063
# t => 5064
# t => 5065
# t => 5066
# t => 5067
# t => 5068
# t => 5069
# t => 5070
# t => 5071
# t => 5072
# t => 5073
# t => 5074
# t => 5075
# t => 5076
# t => 5077
# t => 5078
# t => 5079
# t => 5080
# t => 5081
# t => 5082
# t => 5083
# t => 5084
# t => 5085
# t => 5086
# t => 5087
# t => 5088
# t => 5089
# t => 5090
# t => 5091
# t => 5092
# t => 5093
# t => 5094
# t => 5095
# t => 5096
# t => 5097
# t => 5098
# t => 5099
# t => 5100
# t => 5101
# t => 5102
# t => 5103
# t => 5104
# t => 5105
# t => 5106
# t => 5107
# t => 5108
# t => 5109
# t => 5110
# t => 5111
# t => 5112
# t => 5113
# t => 5114
# t => 5115
# t => 5116
# t => 5117
# t => 5118
# t => 5119
# t => 5120
# t => 5121
# t => 5122
# t => 5123
# t => 5124
# t => 5125
# t => 5126
# t => 5127
# t => 5128
# t => 5129
# t => 5130
# t => 5131
# t => 5132
# t => 5133
# t => 5134
# t => 5135
# t => 5136
# t => 5137
# t => 5138
# t => 5139
# t => 5140
# t => 5141
# t => 5142
# t => 5143
# t => 5144
# t => 5145
# t => 5146
# t => 5147
# t => 5148
# t => 5149
# t => 5150
# t => 5151
# t => 5152
# t => 5153
# t => 5154
# t => 5155
# t => 5156
# t => 5157
# t => 5158
# t => 5159
# t => 5160
# t => 5161
# t => 5162
# t => 5163
# t => 5164
# t => 5165
# t => 5166
# t => 5167
# t => 5168
# t => 5169
# t => 5170
# t => 5171
# t => 5172
# t => 5173
# t => 5174
# t => 5175
# t => 5176
# t => 5177
# t => 5178
# t => 5179
# t => 5180
# t => 5181
# t => 5182
# t => 5183
# t => 5184
# t => 5185
# t => 5186
# t => 5187
# t => 5188
# t => 5189
# t => 5190
# t => 5191
# t => 5192
# t => 5193
# t => 5194
# t => 5195
# t => 5196
# t => 5197
# t => 5198
# t => 5199
# t => 5200
# t => 5201
# t => 5202
# t => 5203
# t => 5204
# t => 5205
# t => 5206
# t => 5207
# t => 5208
# t => 5209
# t => 5210
# t => 5211
# t => 5212
# t => 5213
# t => 5214
# t => 5215
# t => 5216
# t => 5217
# t => 5218
# t => 5219
# t => 5220
# t => 5221
# t => 5222
# t => 5223
# t => 5224
# t => 5225
# t => 5226
# t => 5227
# t => 5228
# t => 5229
# t => 5230
# t => 5231
# t => 5232
# t => 5233
# t => 5234
# t => 5235
# t => 5236
# t => 5237
# t => 5238
# t => 5239
# t => 5240
# t => 5241
# t => 5242
# t => 5243
# t => 5244
# t => 5245
# t => 5246
# t => 5247
# t => 5248
# t => 5249
# t => 5250
# t => 5251
# t => 5252
# t => 5253
# t => 5254
# t => 5255
# t => 5256
# t => 5257
# t => 5258
# t => 5259
# t => 5260
# t => 5261
# t => 5262
# t => 5263
# t => 5264
# t => 5265
# t => 5266
# t => 5267
# t => 5268
# t => 5269
# t => 5270
# t => 5271
# t => 5272
# t => 5273
# t => 5274
# t => 5275
# t => 5276
# t => 5277
# t => 5278
# t => 5279
# t => 5280
# t => 5281
# t => 5282
# t => 5283
# t => 5284
# t => 5285
# t => 5286
# t => 5287
# t => 5288
# t => 5289
# t => 5290
# t => 5291
# t => 5292
# t => 5293
# t => 5294
# t => 5295
# t => 5296
# t => 5297
# t => 5298
# t => 5299
# t => 5300
# t => 5301
# t => 5302
# t => 5303
# t => 5304
# t => 5305
# t => 5306
# t => 5307
# t => 5308
# t => 5309
# t => 5310
# t => 5311
# t => 5312
# t => 5313
# t => 5314
# t => 5315
# t => 5316
# t => 5317
# t => 5318
# t => 5319
# t => 5320
# t => 5321
# t => 5322
# t => 5323
# t => 5324
# t => 5325
# t => 5326
# t => 5327
# t => 5328
# t => 5329
# t => 5330
# t => 5331
# t => 5332
# t => 5333
# t => 5334
# t => 5335
# t => 5336
# t => 5337
# t => 5338
# t => 5339
# t => 5340
# t => 5341
# t => 5342
# t => 5343
# t => 5344
# t => 5345
# t => 5346
# t => 5347
# t => 5348
# t => 5349
# t => 5350
# t => 5351
# t => 5352
# t => 5353
# t => 5354
# t => 5355
# t => 5356
# t => 5357
# t => 5358
# t => 5359
# t => 5360
# t => 5361
# t => 5362
# t => 5363
# t => 5364
# t => 5365
# t => 5366
# t => 5367
# t => 5368
# t => 5369
# t => 5370
# t => 5371
# t => 5372
# t => 5373
# t => 5374
# t => 5375
# t => 5376
# t => 5377
# t => 5378
# t => 5379
# t => 5380
# t => 5381
# t => 5382
# t => 5383
# t => 5384
# t => 5385
# t => 5386
# t => 5387
# t => 5388
# t => 5389
# t => 5390
# t => 5391
# t => 5392
# t => 5393
# t => 5394
# t => 5395
# t => 5396
# t => 5397
# t => 5398
# t => 5399
# t => 5400
# t => 5401
# t => 5402
# t => 5403
# t => 5404
# t => 5405
# t => 5406
# t => 5407
# t => 5408
# t => 5409
# t => 5410
# t => 5411
# t => 5412
# t => 5413
# t => 5414
# t => 5415
# t => 5416
# t => 5417
# t => 5418
# t => 5419
# t => 5420
# t => 5421
# t => 5422
# t => 5423
# t => 5424
# t => 5425
# t => 5426
# t => 5427
# t => 5428
# t => 5429
# t => 5430
# t => 5431
# t => 5432
# t => 5433
# t => 5434
# t => 5435
# t => 5436
# t => 5437
# t => 5438
# t => 5439
# t => 5440
# t => 5441
# t => 5442
# t => 5443
# t => 5444
# t => 5445
# t => 5446
# t => 5447
# t => 5448
# t => 5449
# t => 5450
# t => 5451
# t => 5452
# t => 5453
# t => 5454
# t => 5455
# t => 5456
# t => 5457
# t => 5458
# t => 5459
# t => 5460
# t => 5461
# t => 5462
# t => 5463
# t => 5464
# t => 5465
# t => 5466
# t => 5467
# t => 5468
# t => 5469
# t => 5470
# t => 5471
# t => 5472
# t => 5473
# t => 5474
# t => 5475
# t => 5476
# t => 5477
# t => 5478
# t => 5479
# t => 5480
# t => 5481
# t => 5482
# t => 5483
# t => 5484
# t => 5485
# t => 5486
# t => 5487
# t => 5488
# t => 5489
# t => 5490
# t => 5491
# t => 5492
# t => 5493
# t => 5494
# t => 5495
# t => 5496
# t => 5497
# t => 5498
# t => 5499
# t => 5500
# t => 5501
# t => 5502
# t => 5503
# t => 5504
# t => 5505
# t => 5506
# t => 5507
# t => 5508
# t => 5509
# t => 5510
# t => 5511
# t => 5512
# t => 5513
# t => 5514
# t => 5515
# t => 5516
# t => 5517
# t => 5518
# t => 5519
# t => 5520
# t => 5521
# t => 5522
# t => 5523
# t => 5524
# t => 5525
# t => 5526
# t => 5527
# t => 5528
# t => 5529
# t => 5530
# t => 5531
# t => 5532
# t => 5533
# t => 5534
# t => 5535
# t => 5536
# t => 5537
# t => 5538
# t => 5539
# t => 5540
# t => 5541
# t => 5542
# t => 5543
# t => 5544
# t => 5545
# t => 5546
# t => 5547
# t => 5548
# t => 5549
# t => 5550
# t => 5551
# t => 5552
# t => 5553
# t => 5554
# t => 5555
# t => 5556
# t => 5557
# t => 5558
# t => 5559
# t => 5560
# t => 5561
# t => 5562
# t => 5563
# t => 5564
# t => 5565
# t => 5566
# t => 5567
# t => 5568
# t => 5569
# t => 5570
# t => 5571
# t => 5572
# t => 5573
# t => 5574
# t => 5575
# t => 5576
# t => 5577
# t => 5578
# t => 5579
# t => 5580
# t => 5581
# t => 5582
# t => 5583
# t => 5584
# t => 5585
# t => 5586
# t => 5587
# t => 5588
# t => 5589
# t => 5590
# t => 5591
# t => 5592
# t => 5593
# t => 5594
# t => 5595
# t => 5596
# t => 5597
# t => 5598
# t => 5599
# t => 5600
# t => 5601
# t => 5602
# t => 5603
# t => 5604
# t => 5605
# t => 5606
# t => 5607
# t => 5608
# t => 5609
# t => 5610
# t => 5611
# t => 5612
# t => 5613
# t => 5614
# t => 5615
# t => 5616
# t => 5617
# t => 5618
# t => 5619
# t => 5620
# t => 5621
# t => 5622
# t => 5623
# t => 5624
# t => 5625
# t => 5626
# t => 5627
# t => 5628
# t => 5629
# t => 5630
# t => 5631
# t => 5632
# t => 5633
# t => 5634
# t => 5635
# t => 5636
# t => 5637
# t => 5638
# t => 5639
# t => 5640
# t => 5641
# t => 5642
# t => 5643
# t => 5644
# t => 5645
# t => 5646
# t => 5647
# t => 5648
# t => 5649
# t => 5650
# t => 5651
# t => 5652
# t => 5653
# t => 5654
# t => 5655
# t => 5656
# t => 5657
# t => 5658
# t => 5659
# t => 5660
# t => 5661
# t => 5662
# t => 5663
# t => 5664
# t => 5665
# t => 5666
# t => 5667
# t => 5668
# t => 5669
# t => 5670
# t => 5671
# t => 5672
# t => 5673
# t => 5674
# t => 5675
# t => 5676
# t => 5677
# t => 5678
# t => 5679
# t => 5680
# t => 5681
# t => 5682
# t => 5683
# t => 5684
# t => 5685
# t => 5686
# t => 5687
# t => 5688
# t => 5689
# t => 5690
# t => 5691
# t => 5692
# t => 5693
# t => 5694
# t => 5695
# t => 5696
# t => 5697
# t => 5698
# t => 5699
# t => 5700
# t => 5701
# t => 5702
# t => 5703
# t => 5704
# t => 5705
# t => 5706
# t => 5707
# t => 5708
# t => 5709
# t => 5710
# t => 5711
# t => 5712
# t => 5713
# t => 5714
# t => 5715
# t => 5716
# t => 5717
# t => 5718
# t => 5719
# t => 5720
# t => 5721
# t => 5722
# t => 5723
# t => 5724
# t => 5725
# t => 5726
# t => 5727
# t => 5728
# t => 5729
# t => 5730
# t => 5731
# t => 5732
# t => 5733
# t => 5734
# t => 5735
# t => 5736
# t => 5737
# t => 5738
# t => 5739
# t => 5740
# t => 5741
# t => 5742
# t => 5743
# t => 5744
# t => 5745
# t => 5746
# t => 5747
# t => 5748
# t => 5749
# t => 5750
# t => 5751
# t => 5752
# t => 5753
# t => 5754
# t => 5755
# t => 5756
# t => 5757
# t => 5758
# t => 5759
# t => 5760
# t => 5761
# t => 5762
# t => 5763
# t => 5764
# t => 5765
# t => 5766
# t => 5767
# t => 5768
# t => 5769
# t => 5770
# t => 5771
# t => 5772
# t => 5773
# t => 5774
# t => 5775
# t => 5776
# t => 5777
# t => 5778
# t => 5779
# t => 5780
# t => 5781
# t => 5782
# t => 5783
# t => 5784
# t => 5785
# t => 5786
# t => 5787
# t => 5788
# t => 5789
# t => 5790
# t => 5791
# t => 5792
# t => 5793
# t => 5794
# t => 5795
# t => 5796
# t => 5797
# t => 5798
# t => 5799
# t => 5800
# t => 5801
# t => 5802
# t => 5803
# t => 5804
# t => 5805
# t => 5806
# t => 5807
# t => 5808
# t => 5809
# t => 5810
# t => 5811
# t => 5812
# t => 5813
# t => 5814
# t => 5815
# t => 5816
# t => 5817
# t => 5818
# t => 5819
# t => 5820
# t => 5821
# t => 5822
# t => 5823
# t => 5824
# t => 5825
# t => 5826
# t => 5827
# t => 5828
# t => 5829
# t => 5830
# t => 5831
# t => 5832
# t => 5833
# t => 5834
# t => 5835
# t => 5836
# t => 5837
# t => 5838
# t => 5839
# t => 5840
# t => 5841
# t => 5842
# t => 5843
# t => 5844
# t => 5845
# t => 5846
# t => 5847
# t => 5848
# t => 5849
# t => 5850
# t => 5851
# t => 5852
# t => 5853
# t => 5854
# t => 5855
# t => 5856
# t => 5857
# t => 5858
# t => 5859
# t => 5860
# t => 5861
# t => 5862
# t => 5863
# t => 5864
# t => 5865
# t => 5866
# t => 5867
# t => 5868
# t => 5869
# t => 5870
# t => 5871
# t => 5872
# t => 5873
# t => 5874
# t => 5875
# t => 5876
# t => 5877
# t => 5878
# t => 5879
# t => 5880
# t => 5881
# t => 5882
# t => 5883
# t => 5884
# t => 5885
# t => 5886
# t => 5887
# t => 5888
# t => 5889
# t => 5890
# t => 5891
# t => 5892
# t => 5893
# t => 5894
# t => 5895
# t => 5896
# t => 5897
# t => 5898
# t => 5899
# t => 5900
# t => 5901
# t => 5902
# t => 5903
# t => 5904
# t => 5905
# t => 5906
# t => 5907
# t => 5908
# t => 5909
# t => 5910
# t => 5911
# t => 5912
# t => 5913
# t => 5914
# t => 5915
# t => 5916
# t => 5917
# t => 5918
# t => 5919
# t => 5920
# t => 5921
# t => 5922
# t => 5923
# t => 5924
# t => 5925
# t => 5926
# t => 5927
# t => 5928
# t => 5929
# t => 5930
# t => 5931
# t => 5932
# t => 5933
# t => 5934
# t => 5935
# t => 5936
# t => 5937
# t => 5938
# t => 5939
# t => 5940
# t => 5941
# t => 5942
# t => 5943
# t => 5944
# t => 5945
# t => 5946
# t => 5947
# t => 5948
# t => 5949
# t => 5950
# t => 5951
# t => 5952
# t => 5953
# t => 5954
# t => 5955
# t => 5956
# t => 5957
# t => 5958
# t => 5959
# t => 5960
# t => 5961
# t => 5962
# t => 5963
# t => 5964
# t => 5965
# t => 5966
# t => 5967
# t => 5968
# t => 5969
# t => 5970
# t => 5971
# t => 5972
# t => 5973
# t => 5974
# t => 5975
# t => 5976
# t => 5977
# t => 5978
# t => 5979
# t => 5980
# t => 5981
# t => 5982
# t => 5983
# t => 5984
# t => 5985
# t => 5986
# t => 5987
# t => 5988
# t => 5989
# t => 5990
# t => 5991
# t => 5992
# t => 5993
# t => 5994
# t => 5995
# t => 5996
# t => 5997
# t => 5998
# t => 5999
# t => 6000
# t => 6001
# t => 6002
# t => 6003
# t => 6004
# t => 6005
# t => 6006
# t => 6007
# t => 6008
# t => 6009
# t => 6010
# t => 6011
# t => 6012
# t => 6013
# t => 6014
# t => 6015
# t => 6016
# t => 6017
# t => 6018
# t => 6019
# t => 6020
# t => 6021
# t => 6022
# t => 6023
# t => 6024
# t => 6025
# t => 6026
# t => 6027
# t => 6028
# t => 6029
# t => 6030
# t => 6031
# t => 6032
# t => 6033
# t => 6034
# t => 6035
# t => 6036
# t => 6037
# t => 6038
# t => 6039
# t => 6040
# t => 6041
# t => 6042
# t => 6043
# t => 6044
# t => 6045
# t => 6046
# t => 6047
# t => 6048
# t => 6049
# t => 6050
# t => 6051
# t => 6052
# t => 6053
# t => 6054
# t => 6055
# t => 6056
# t => 6057
# t => 6058
# t => 6059
# t => 6060
# t => 6061
# t => 6062
# t => 6063
# t => 6064
# t => 6065
# t => 6066
# t => 6067
# t => 6068
# t => 6069
# t => 6070
# t => 6071
# t => 6072
# t => 6073
# t => 6074
# t => 6075
# t => 6076
# t => 6077
# t => 6078
# t => 6079
# t => 6080
# t => 6081
# t => 6082
# t => 6083
# t => 6084
# t => 6085
# t => 6086
# t => 6087
# t => 6088
# t => 6089
# t => 6090
# t => 6091
# t => 6092
# t => 6093
# t => 6094
# t => 6095
# t => 6096
# t => 6097
# t => 6098
# t => 6099
# t => 6100
# t => 6101
# t => 6102
# t => 6103
# t => 6104
# t => 6105
# t => 6106
# t => 6107
# t => 6108
# t => 6109
# t => 6110
# t => 6111
# t => 6112
# t => 6113
# t => 6114
# t => 6115
# t => 6116
# t => 6117
# t => 6118
# t => 6119
# t => 6120
# t => 6121
# t => 6122
# t => 6123
# t => 6124
# t => 6125
# t => 6126
# t => 6127
# t => 6128
# t => 6129
# t => 6130
# t => 6131
# t => 6132
# t => 6133
# t => 6134
# t => 6135
# t => 6136
# t => 6137
# t => 6138
# t => 6139
# t => 6140
# t => 6141
# t => 6142
# t => 6143
# t => 6144
# t => 6145
# t => 6146
# t => 6147
# t => 6148
# t => 6149
# t => 6150
# t => 6151
# t => 6152
# t => 6153
# t => 6154
# t => 6155
# t => 6156
# t => 6157
# t => 6158
# t => 6159
# t => 6160
# t => 6161
# t => 6162
# t => 6163
# t => 6164
# t => 6165
# t => 6166
# t => 6167
# t => 6168
# t => 6169
# t => 6170
# t => 6171
# t => 6172
# t => 6173
# t => 6174
# t => 6175
# t => 6176
# t => 6177
# t => 6178
# t => 6179
# t => 6180
# t => 6181
# t => 6182
# t => 6183
# t => 6184
# t => 6185
# t => 6186
# t => 6187
# t => 6188
# t => 6189
# t => 6190
# t => 6191
# t => 6192
# t => 6193
# t => 6194
# t => 6195
# t => 6196
# t => 6197
# t => 6198
# t => 6199
# t => 6200
# t => 6201
# t => 6202
# t => 6203
# t => 6204
# t => 6205
# t => 6206
# t => 6207
# t => 6208
# t => 6209
# t => 6210
# t => 6211
# t => 6212
# t => 6213
# t => 6214
# t => 6215
# t => 6216
# t => 6217
# t => 6218
# t => 6219
# t => 6220
# t => 6221
# t => 6222
# t => 6223
# t => 6224
# t => 6225
# t => 6226
# t => 6227
# t => 6228
# t => 6229
# t => 6230
# t => 6231
# t => 6232
# t => 6233
# t => 6234
# t => 6235
# t => 6236
# t => 6237
# t => 6238
# t => 6239
# t => 6240
# t => 6241
# t => 6242
# t => 6243
# t => 6244
# t => 6245
# t => 6246
# t => 6247
# t => 6248
# t => 6249
# t => 6250
# t => 6251
# t => 6252
# t => 6253
# t => 6254
# t => 6255
# t => 6256
# t => 6257
# t => 6258
# t => 6259
# t => 6260
# t => 6261
# t => 6262
# t => 6263
# t => 6264
# t => 6265
# t => 6266
# t => 6267
# t => 6268
# t => 6269
# t => 6270
# t => 6271
# t => 6272
# t => 6273
# t => 6274
# t => 6275
# t => 6276
# t => 6277
# t => 6278
# t => 6279
# t => 6280
# t => 6281
# t => 6282
# t => 6283
# t => 6284
# t => 6285
# t => 6286
# t => 6287
# t => 6288
# t => 6289
# t => 6290
# t => 6291
# t => 6292
# t => 6293
# t => 6294
# t => 6295
# t => 6296
# t => 6297
# t => 6298
# t => 6299
# t => 6300
# t => 6301
# t => 6302
# t => 6303
# t => 6304
# t => 6305
# t => 6306
# t => 6307
# t => 6308
# t => 6309
# t => 6310
# t => 6311
# t => 6312
# t => 6313
# t => 6314
# t => 6315
# t => 6316
# t => 6317
# t => 6318
# t => 6319
# t => 6320
# t => 6321
# t => 6322
# t => 6323
# t => 6324
# t => 6325
# t => 6326
# t => 6327
# t => 6328
# t => 6329
# t => 6330
# t => 6331
# t => 6332
# t => 6333
# t => 6334
# t => 6335
# t => 6336
# t => 6337
# t => 6338
# t => 6339
# t => 6340
# t => 6341
# t => 6342
# t => 6343
# t => 6344
# t => 6345
# t => 6346
# t => 6347
# t => 6348
# t => 6349
# t => 6350
# t => 6351
# t => 6352
# t => 6353
# t => 6354
# t => 6355
# t => 6356
# t => 6357
# t => 6358
# t => 6359
# t => 6360
# t => 6361
# t => 6362
# t => 6363
# t => 6364
# t => 6365
# t => 6366
# t => 6367
# t => 6368
# t => 6369
# t => 6370
# t => 6371
# t => 6372
# t => 6373
# t => 6374
# t => 6375
# t => 6376
# t => 6377
# t => 6378
# t => 6379
# t => 6380
# t => 6381
# t => 6382
# t => 6383
# t => 6384
# t => 6385
# t => 6386
# t => 6387
# t => 6388
# t => 6389
# t => 6390
# t => 6391
# t => 6392
# t => 6393
# t => 6394
# t => 6395
# t => 6396
# t => 6397
# t => 6398
# t => 6399
# t => 6400
# t => 6401
# t => 6402
# t => 6403
# t => 6404
# t => 6405
# t => 6406
# t => 6407
# t => 6408
# t => 6409
# t => 6410
# t => 6411
# t => 6412
# t => 6413
# t => 6414
# t => 6415
# t => 6416
# t => 6417
# t => 6418
# t => 6419
# t => 6420
# t => 6421
# t => 6422
# t => 6423
# t => 6424
# t => 6425
# t => 6426
# t => 6427
# t => 6428
# t => 6429
# t => 6430
# t => 6431
# t => 6432
# t => 6433
# t => 6434
# t => 6435
# t => 6436
# t => 6437
# t => 6438
# t => 6439
# t => 6440
# t => 6441
# t => 6442
# t => 6443
# t => 6444
# t => 6445
# t => 6446
# t => 6447
# t => 6448
# t => 6449
# t => 6450
# t => 6451
# t => 6452
# t => 6453
# t => 6454
# t => 6455
# t => 6456
# t => 6457
# t => 6458
# t => 6459
# t => 6460
# t => 6461
# t => 6462
# t => 6463
# t => 6464
# t => 6465
# t => 6466
# t => 6467
# t => 6468
# t => 6469
# t => 6470
# t => 6471
# t => 6472
# t => 6473
# t => 6474
# t => 6475
# t => 6476
# t => 6477
# t => 6478
# t => 6479
# t => 6480
# t => 6481
# t => 6482
# t => 6483
# t => 6484
# t => 6485
# t => 6486
# t => 6487
# t => 6488
# t => 6489
# t => 6490
# t => 6491
# t => 6492
# t => 6493
# t => 6494
# t => 6495
# t => 6496
# t => 6497
# t => 6498
# t => 6499
# t => 6500
# t => 6501
# t => 6502
# t => 6503
# t => 6504
# t => 6505
# t => 6506
# t => 6507
# t => 6508
# t => 6509
# t => 6510
# t => 6511
# t => 6512
# t => 6513
# t => 6514
# t => 6515
# t => 6516
# t => 6517
# t => 6518
# t => 6519
# t => 6520
# t => 6521
# t => 6522
# t => 6523
# t => 6524
# t => 6525
# t => 6526
# t => 6527
# t => 6528
# t => 6529
# t => 6530
# t => 6531
# t => 6532
# t => 6533
# t => 6534
# t => 6535
# t => 6536
# t => 6537
# t => 6538
# t => 6539
# t => 6540
# t => 6541
# t => 6542
# t => 6543
# t => 6544
# t => 6545
# t => 6546
# t => 6547
# t => 6548
# t => 6549
# t => 6550
# t => 6551
# t => 6552
# t => 6553
# t => 6554
# t => 6555
# t => 6556
# t => 6557
# t => 6558
# t => 6559
# t => 6560
# t => 6561
# t => 6562
# t => 6563
# t => 6564
# t => 6565
# t => 6566
# t => 6567
# t => 6568
# t => 6569
# t => 6570
# t => 6571
# t => 6572
# t => 6573
# t => 6574
# t => 6575
# t => 6576
# t => 6577
# t => 6578
# t => 6579
# t => 6580
# t => 6581
# t => 6582
# t => 6583
# t => 6584
# t => 6585
# t => 6586
# t => 6587
# t => 6588
# t => 6589
# t => 6590
# t => 6591
# t => 6592
# t => 6593
# t => 6594
# t => 6595
# t => 6596
# t => 6597
# t => 6598
# t => 6599
# t => 6600
# t => 6601
# t => 6602
# t => 6603
# t => 6604
# t => 6605
# t => 6606
# t => 6607
# t => 6608
# t => 6609
# t => 6610
# t => 6611
# t => 6612
# t => 6613
# t => 6614
# t => 6615
# t => 6616
# t => 6617
# t => 6618
# t => 6619
# t => 6620
# t => 6621
# t => 6622
# t => 6623
# t => 6624
# t => 6625
# t => 6626
# t => 6627
# t => 6628
# t => 6629
# t => 6630
# t => 6631
# t => 6632
# t => 6633
# t => 6634
# t => 6635
# t => 6636
# t => 6637
# t => 6638
# t => 6639
# t => 6640
# t => 6641
# t => 6642
# t => 6643
# t => 6644
# t => 6645
# t => 6646
# t => 6647
# t => 6648
# t => 6649
# t => 6650
# t => 6651
# t => 6652
# t => 6653
# t => 6654
# t => 6655
# t => 6656
# t => 6657
# t => 6658
# t => 6659
# t => 6660
# t => 6661
# t => 6662
# t => 6663
# t => 6664
# t => 6665
# t => 6666
# t => 6667
# t => 6668
# t => 6669
# t => 6670
# t => 6671
# t => 6672
# t => 6673
# t => 6674
# t => 6675
# t => 6676
# t => 6677
# t => 6678
# t => 6679
# t => 6680
# t => 6681
# t => 6682
# t => 6683
# t => 6684
# t => 6685
# t => 6686
# t => 6687
# t => 6688
# t => 6689
# t => 6690
# t => 6691
# t => 6692
# t => 6693
# t => 6694
# t => 6695
# t => 6696
# t => 6697
# t => 6698
# t => 6699
# t => 6700
# t => 6701
# t => 6702
# t => 6703
# t => 6704
# t => 6705
# t => 6706
# t => 6707
# t => 6708
# t => 6709
# t => 6710
# t => 6711
# t => 6712
# t => 6713
# t => 6714
# t => 6715
# t => 6716
# t => 6717
# t => 6718
# t => 6719
# t => 6720
# t => 6721
# t => 6722
# t => 6723
# t => 6724
# t => 6725
# t => 6726
# t => 6727
# t => 6728
# t => 6729
# t => 6730
# t => 6731
# t => 6732
# t => 6733
# t => 6734
# t => 6735
# t => 6736
# t => 6737
# t => 6738
# t => 6739
# t => 6740
# t => 6741
# t => 6742
# t => 6743
# t => 6744
# t => 6745
# t => 6746
# t => 6747
# t => 6748
# t => 6749
# t => 6750
# t => 6751
# t => 6752
# t => 6753
# t => 6754
# t => 6755
# t => 6756
# t => 6757
# t => 6758
# t => 6759
# t => 6760
# t => 6761
# t => 6762
# t => 6763
# t => 6764
# t => 6765
# t => 6766
# t => 6767
# t => 6768
# t => 6769
# t => 6770
# t => 6771
# t => 6772
# t => 6773
# t => 6774
# t => 6775
# t => 6776
# t => 6777
# t => 6778
# t => 6779
# t => 6780
# t => 6781
# t => 6782
# t => 6783
# t => 6784
# t => 6785
# t => 6786
# t => 6787
# t => 6788
# t => 6789
# t => 6790
# t => 6791
# t => 6792
# t => 6793
# t => 6794
# t => 6795
# t => 6796
# t => 6797
# t => 6798
# t => 6799
# t => 6800
# t => 6801
# t => 6802
# t => 6803
# t => 6804
# t => 6805
# t => 6806
# t => 6807
# t => 6808
# t => 6809
# t => 6810
# t => 6811
# t => 6812
# t => 6813
# t => 6814
# t => 6815
# t => 6816
# t => 6817
# t => 6818
# t => 6819
# t => 6820
# t => 6821
# t => 6822
# t => 6823
# t => 6824
# t => 6825
# t => 6826
# t => 6827
# t => 6828
# t => 6829
# t => 6830
# t => 6831
# t => 6832
# t => 6833
# t => 6834
# t => 6835
# t => 6836
# t => 6837
# t => 6838
# t => 6839
# t => 6840
# t => 6841
# t => 6842
# t => 6843
# t => 6844
# t => 6845
# t => 6846
# t => 6847
# t => 6848
# t => 6849
# t => 6850
# t => 6851
# t => 6852
# t => 6853
# t => 6854
# t => 6855
# t => 6856
# t => 6857
# t => 6858
# t => 6859
# t => 6860
# t => 6861
# t => 6862
# t => 6863
# t => 6864
# t => 6865
# t => 6866
# t => 6867
# t => 6868
# t => 6869
# t => 6870
# t => 6871
# t => 6872
# t => 6873
# t => 6874
# t => 6875
# t => 6876
# t => 6877
# t => 6878
# t => 6879
# t => 6880
# t => 6881
# t => 6882
# t => 6883
# t => 6884
# t => 6885
# t => 6886
# t => 6887
# t => 6888
# t => 6889
# t => 6890
# t => 6891
# t => 6892
# t => 6893
# t => 6894
# t => 6895
# t => 6896
# t => 6897
# t => 6898
# t => 6899
# t => 6900
# t => 6901
# t => 6902
# t => 6903
# t => 6904
# t => 6905
# t => 6906
# t => 6907
# t => 6908
# t => 6909
# t => 6910
# t => 6911
# t => 6912
# t => 6913
# t => 6914
# t => 6915
# t => 6916
# t => 6917
# t => 6918
# t => 6919
# t => 6920
# t => 6921
# t => 6922
# t => 6923
# t => 6924
# t => 6925
# t => 6926
# t => 6927
# t => 6928
# t => 6929
# t => 6930
# t => 6931
# t => 6932
# t => 6933
# t => 6934
# t => 6935
# t => 6936
# t => 6937
# t => 6938
# t => 6939
# t => 6940
# t => 6941
# t => 6942
# t => 6943
# t => 6944
# t => 6945
# t => 6946
# t => 6947
# t => 6948
# t => 6949
# t => 6950
# t => 6951
# t => 6952
# t => 6953
# t => 6954
# t => 6955
# t => 6956
# t => 6957
# t => 6958
# t => 6959
# t => 6960
# t => 6961
# t => 6962
# t => 6963
# t => 6964
# t => 6965
# t => 6966
# t => 6967
# t => 6968
# t => 6969
# t => 6970
# t => 6971
# t => 6972
# t => 6973
# t => 6974
# t => 6975
# t => 6976
# t => 6977
# t => 6978
# t => 6979
# t => 6980
# t => 6981
# t => 6982
# t => 6983
# t => 6984
# t => 6985
# t => 6986
# t => 6987
# t => 6988
# t => 6989
# t => 6990
# t => 6991
# t => 6992
# t => 6993
# t => 6994
# t => 6995
# t => 6996
# t => 6997
# t => 6998
# t => 6999
# t => 7000
# t => 7001
# t => 7002
# t => 7003
# t => 7004
# t => 7005
# t => 7006
# t => 7007
# t => 7008
# t => 7009
# t => 7010
# t => 7011
# t => 7012
# t => 7013
# t => 7014
# t => 7015
# t => 7016
# t => 7017
# t => 7018
# t => 7019
# t => 7020
# t => 7021
# t => 7022
# t => 7023
# t => 7024
# t => 7025
# t => 7026
# t => 7027
# t => 7028
# t => 7029
# t => 7030
# t => 7031
# t => 7032
# t => 7033
# t => 7034
# t => 7035
# t => 7036
# t => 7037
# t => 7038
# t => 7039
# t => 7040
# t => 7041
# t => 7042
# t => 7043
# t => 7044
# t => 7045
# t => 7046
# t => 7047
# t => 7048
# t => 7049
# t => 7050
# t => 7051
# t => 7052
# t => 7053
# t => 7054
# t => 7055
# t => 7056
# t => 7057
# t => 7058
# t => 7059
# t => 7060
# t => 7061
# t => 7062
# t => 7063
# t => 7064
# t => 7065
# t => 7066
# t => 7067
# t => 7068
# t => 7069
# t => 7070
# t => 7071
# t => 7072
# t => 7073
# t => 7074
# t => 7075
# t => 7076
# t => 7077
# t => 7078
# t => 7079
# t => 7080
# t => 7081
# t => 7082
# t => 7083
# t => 7084
# t => 7085
# t => 7086
# t => 7087
# t => 7088
# t => 7089
# t => 7090
# t => 7091
# t => 7092
# t => 7093
# t => 7094
# t => 7095
# t => 7096
# t => 7097
# t => 7098
# t => 7099
# t => 7100
# t => 7101
# t => 7102
# t => 7103
# t => 7104
# t => 7105
# t => 7106
# t => 7107
# t => 7108
# t => 7109
# t => 7110
# t => 7111
# t => 7112
# t => 7113
# t => 7114
# t => 7115
# t => 7116
# t => 7117
# t => 7118
# t => 7119
# t => 7120
# t => 7121
# t => 7122
# t => 7123
# t => 7124
# t => 7125
# t => 7126
# t => 7127
# t => 7128
# t => 7129
# t => 7130
# t => 7131
# t => 7132
# t => 7133
# t => 7134
# t => 7135
# t => 7136
# t => 7137
# t => 7138
# t => 7139
# t => 7140
# t => 7141
# t => 7142
# t => 7143
# t => 7144
# t => 7145
# t => 7146
# t => 7147
# t => 7148
# t => 7149
# t => 7150
# t => 7151
# t => 7152
# t => 7153
# t => 7154
# t => 7155
# t => 7156
# t => 7157
# t => 7158
# t => 7159
# t => 7160
# t => 7161
# t => 7162
# t => 7163
# t => 7164
# t => 7165
# t => 7166
# t => 7167
# t => 7168
# t => 7169
# t => 7170
# t => 7171
# t => 7172
# t => 7173
# t => 7174
# t => 7175
# t => 7176
# t => 7177
# t => 7178
# t => 7179
# t => 7180
# t => 7181
# t => 7182
# t => 7183
# t => 7184
# t => 7185
# t => 7186
# t => 7187
# t => 7188
# t => 7189
# t => 7190
# t => 7191
# t => 7192
# t => 7193
# t => 7194
# t => 7195
# t => 7196
# t => 7197
# t => 7198
# t => 7199
# t => 7200
# t => 7201
# t => 7202
# t => 7203
# t => 7204
# t => 7205
# t => 7206
# t => 7207
# t => 7208
# t => 7209
# t => 7210
# t => 7211
# t => 7212
# t => 7213
# t => 7214
# t => 7215
# t => 7216
# t => 7217
# t => 7218
# t => 7219
# t => 7220
# t => 7221
# t => 7222
# t => 7223
# t => 7224
# t => 7225
# t => 7226
# t => 7227
# t => 7228
# t => 7229
# t => 7230
# t => 7231
# t => 7232
# t => 7233
# t => 7234
# t => 7235
# t => 7236
# t => 7237
# t => 7238
# t => 7239
# t => 7240
# t => 7241
# t => 7242
# t => 7243
# t => 7244
# t => 7245
# t => 7246
# t => 7247
# t => 7248
# t => 7249
# t => 7250
# t => 7251
# t => 7252
# t => 7253
# t => 7254
# t => 7255
# t => 7256
# t => 7257
# t => 7258
# t => 7259
# t => 7260
# t => 7261
# t => 7262
# t => 7263
# t => 7264
# t => 7265
# t => 7266
# t => 7267
# t => 7268
# t => 7269
# t => 7270
# t => 7271
# t => 7272
# t => 7273
# t => 7274
# t => 7275
# t => 7276
# t => 7277
# t => 7278
# t => 7279
# t => 7280
# t => 7281
# t => 7282
# t => 7283
# t => 7284
# t => 7285
# t => 7286
# t => 7287
# t => 7288
# t => 7289
# t => 7290
# t => 7291
# t => 7292
# t => 7293
# t => 7294
# t => 7295
# t => 7296
# t => 7297
# t => 7298
# t => 7299
# t => 7300
# t => 7301
# t => 7302
# t => 7303
# t => 7304
# t => 7305
# t => 7306
# t => 7307
# t => 7308
# t => 7309
# t => 7310
# t => 7311
# t => 7312
# t => 7313
# t => 7314
# t => 7315
# t => 7316
# t => 7317
# t => 7318
# t => 7319
# t => 7320
# t => 7321
# t => 7322
# t => 7323
# t => 7324
# t => 7325
# t => 7326
# t => 7327
# t => 7328
# t => 7329
# t => 7330
# t => 7331
# t => 7332
# t => 7333
# t => 7334
# t => 7335
# t => 7336
# t => 7337
# t => 7338
# t => 7339
# t => 7340
# t => 7341
# t => 7342
# t => 7343
# t => 7344
# t => 7345
# t => 7346
# t => 7347
# t => 7348
# t => 7349
# t => 7350
# t => 7351
# t => 7352
# t => 7353
# t => 7354
# t => 7355
# t => 7356
# t => 7357
# t => 7358
# t => 7359
# t => 7360
# t => 7361
# t => 7362
# t => 7363
# t => 7364
# t => 7365
# t => 7366
# t => 7367
# t => 7368
# t => 7369
# t => 7370
# t => 7371
# t => 7372
# t => 7373
# t => 7374
# t => 7375
# t => 7376
# t => 7377
# t => 7378
# t => 7379
# t => 7380
# t => 7381
# t => 7382
# t => 7383
# t => 7384
# t => 7385
# t => 7386
# t => 7387
# t => 7388
# t => 7389
# t => 7390
# t => 7391
# t => 7392
# t => 7393
# t => 7394
# t => 7395
# t => 7396
# t => 7397
# t => 7398
# t => 7399
# t => 7400
# t => 7401
# t => 7402
# t => 7403
# t => 7404
# t => 7405
# t => 7406
# t => 7407
# t => 7408
# t => 7409
# t => 7410
# t => 7411
# t => 7412
# t => 7413
# t => 7414
# t => 7415
# t => 7416
# t => 7417
# t => 7418
# t => 7419
# t => 7420
# t => 7421
# t => 7422
# t => 7423
# t => 7424
# t => 7425
# t => 7426
# t => 7427
# t => 7428
# t => 7429
# t => 7430
# t => 7431
# t => 7432
# t => 7433
# t => 7434
# t => 7435
# t => 7436
# t => 7437
# t => 7438
# t => 7439
# t => 7440
# t => 7441
# t => 7442
# t => 7443
# t => 7444
# t => 7445
# t => 7446
# t => 7447
# t => 7448
# t => 7449
# t => 7450
# t => 7451
# t => 7452
# t => 7453
# t => 7454
# t => 7455
# t => 7456
# t => 7457
# t => 7458
# t => 7459
# t => 7460
# t => 7461
# t => 7462
# t => 7463
# t => 7464
# t => 7465
# t => 7466
# t => 7467
# t => 7468
# t => 7469
# t => 7470
# t => 7471
# t => 7472
# t => 7473
# t => 7474
# t => 7475
# t => 7476
# t => 7477
# t => 7478
# t => 7479
# t => 7480
# t => 7481
# t => 7482
# t => 7483
# t => 7484
# t => 7485
# t => 7486
# t => 7487
# t => 7488
# t => 7489
# t => 7490
# t => 7491
# t => 7492
# t => 7493
# t => 7494
# t => 7495
# t => 7496
# t => 7497
# t => 7498
# t => 7499
# t => 7500
# t => 7501
# t => 7502
# t => 7503
# t => 7504
# t => 7505
# t => 7506
# t => 7507
# t => 7508
# t => 7509
# t => 7510
# t => 7511
# t => 7512
# t => 7513
# t => 7514
# t => 7515
# t => 7516
# t => 7517
# t => 7518
# t => 7519
# t => 7520
# t => 7521
# t => 7522
# t => 7523
# t => 7524
# t => 7525
# t => 7526
# t => 7527
# t => 7528
# t => 7529
# t => 7530
# t => 7531
# t => 7532
# t => 7533
# t => 7534
# t => 7535
# t => 7536
# t => 7537
# t => 7538
# t => 7539
# t => 7540
# t => 7541
# t => 7542
# t => 7543
# t => 7544
# t => 7545
# t => 7546
# t => 7547
# t => 7548
# t => 7549
# t => 7550
# t => 7551
# t => 7552
# t => 7553
# t => 7554
# t => 7555
# t => 7556
# t => 7557
# t => 7558
# t => 7559
# t => 7560
# t => 7561
# t => 7562
# t => 7563
# t => 7564
# t => 7565
# t => 7566
# t => 7567
# t => 7568
# t => 7569
# t => 7570
# t => 7571
# t => 7572
# t => 7573
# t => 7574
# t => 7575
# t => 7576
# t => 7577
# t => 7578
# t => 7579
# t => 7580
# t => 7581
# t => 7582
# t => 7583
# t => 7584
# t => 7585
# t => 7586
# t => 7587
# t => 7588
# t => 7589
# t => 7590
# t => 7591
# t => 7592
# t => 7593
# t => 7594
# t => 7595
# t => 7596
# t => 7597
# t => 7598
# t => 7599
# t => 7600
# t => 7601
# t => 7602
# t => 7603
# t => 7604
# t => 7605
# t => 7606
# t => 7607
# t => 7608
# t => 7609
# t => 7610
# t => 7611
# t => 7612
# t => 7613
# t => 7614
# t => 7615
# t => 7616
# t => 7617
# t => 7618
# t => 7619
# t => 7620
# t => 7621
# t => 7622
# t => 7623
# t => 7624
# t => 7625
# t => 7626
# t => 7627
# t => 7628
# t => 7629
# t => 7630
# t => 7631
# t => 7632
# t => 7633
# t => 7634
# t => 7635
# t => 7636
# t => 7637
# t => 7638
# t => 7639
# t => 7640
# t => 7641
# t => 7642
# t => 7643
# t => 7644
# t => 7645
# t => 7646
# t => 7647
# t => 7648
# t => 7649
# t => 7650
# t => 7651
# t => 7652
# t => 7653
# t => 7654
# t => 7655
# t => 7656
# t => 7657
# t => 7658
# t => 7659
# t => 7660
# t => 7661
# t => 7662
# t => 7663
# t => 7664
# t => 7665
# t => 7666
# t => 7667
# t => 7668
# t => 7669
# t => 7670
# t => 7671
# t => 7672
# t => 7673
# t => 7674
# t => 7675
# t => 7676
# t => 7677
# t => 7678
# t => 7679
# t => 7680
# t => 7681
# t => 7682
# t => 7683
# t => 7684
# t => 7685
# t => 7686
# t => 7687
# t => 7688
# t => 7689
# t => 7690
# t => 7691
# t => 7692
# t => 7693
# t => 7694
# t => 7695
# t => 7696
# t => 7697
# t => 7698
# t => 7699
# t => 7700
# t => 7701
# t => 7702
# t => 7703
# t => 7704
# t => 7705
# t => 7706
# t => 7707
# t => 7708
# t => 7709
# t => 7710
# t => 7711
# t => 7712
# t => 7713
# t => 7714
# t => 7715
# t => 7716
# t => 7717
# t => 7718
# t => 7719
# t => 7720
# t => 7721
# t => 7722
# t => 7723
# t => 7724
# t => 7725
# t => 7726
# t => 7727
# t => 7728
# t => 7729
# t => 7730
# t => 7731
# t => 7732
# t => 7733
# t => 7734
# t => 7735
# t => 7736
# t => 7737
# t => 7738
# t => 7739
# t => 7740
# t => 7741
# t => 7742
# t => 7743
# t => 7744
# t => 7745
# t => 7746
# t => 7747
# t => 7748
# t => 7749
# t => 7750
# t => 7751
# t => 7752
# t => 7753
# t => 7754
# t => 7755
# t => 7756
# t => 7757
# t => 7758
# t => 7759
# t => 7760
# t => 7761
# t => 7762
# t => 7763
# t => 7764
# t => 7765
# t => 7766
# t => 7767
# t => 7768
# t => 7769
# t => 7770
# t => 7771
# t => 7772
# t => 7773
# t => 7774
# t => 7775
# t => 7776
# t => 7777
# t => 7778
# t => 7779
# t => 7780
# t => 7781
# t => 7782
# t => 7783
# t => 7784
# t => 7785
# t => 7786
# t => 7787
# t => 7788
# t => 7789
# t => 7790
# t => 7791
# t => 7792
# t => 7793
# t => 7794
# t => 7795
# t => 7796
# t => 7797
# t => 7798
# t => 7799
# t => 7800
# t => 7801
# t => 7802
# t => 7803
# t => 7804
# t => 7805
# t => 7806
# t => 7807
# t => 7808
# t => 7809
# t => 7810
# t => 7811
# t => 7812
# t => 7813
# t => 7814
# t => 7815
# t => 7816
# t => 7817
# t => 7818
# t => 7819
# t => 7820
# t => 7821
# t => 7822
# t => 7823
# t => 7824
# t => 7825
# t => 7826
# t => 7827
# t => 7828
# t => 7829
# t => 7830
# t => 7831
# t => 7832
# t => 7833
# t => 7834
# t => 7835
# t => 7836
# t => 7837
# t => 7838
# t => 7839
# t => 7840
# t => 7841
# t => 7842
# t => 7843
# t => 7844
# t => 7845
# t => 7846
# t => 7847
# t => 7848
# t => 7849
# t => 7850
# t => 7851
# t => 7852
# t => 7853
# t => 7854
# t => 7855
# t => 7856
# t => 7857
# t => 7858
# t => 7859
# t => 7860
# t => 7861
# t => 7862
# t => 7863
# t => 7864
# t => 7865
# t => 7866
# t => 7867
# t => 7868
# t => 7869
# t => 7870
# t => 7871
# t => 7872
# t => 7873
# t => 7874
# t => 7875
# t => 7876
# t => 7877
# t => 7878
# t => 7879
# t => 7880
# t => 7881
# t => 7882
# t => 7883
# t => 7884
# t => 7885
# t => 7886
# t => 7887
# t => 7888
# t => 7889
# t => 7890
# t => 7891
# t => 7892
# t => 7893
# t => 7894
# t => 7895
# t => 7896
# t => 7897
# t => 7898
# t => 7899
# t => 7900
# t => 7901
# t => 7902
# t => 7903
# t => 7904
# t => 7905
# t => 7906
# t => 7907
# t => 7908
# t => 7909
# t => 7910
# t => 7911
# t => 7912
# t => 7913
# t => 7914
# t => 7915
# t => 7916
# t => 7917
# t => 7918
# t => 7919
# t => 7920
# t => 7921
# t => 7922
# t => 7923
# t => 7924
# t => 7925
# t => 7926
# t => 7927
# t => 7928
# t => 7929
# t => 7930
# t => 7931
# t => 7932
# t => 7933
# t => 7934
# t => 7935
# t => 7936
# t => 7937
# t => 7938
# t => 7939
# t => 7940
# t => 7941
# t => 7942
# t => 7943
# t => 7944
# t => 7945
# t => 7946
# t => 7947
# t => 7948
# t => 7949
# t => 7950
# t => 7951
# t => 7952
# t => 7953
# t => 7954
# t => 7955
# t => 7956
# t => 7957
# t => 7958
# t => 7959
# t => 7960
# t => 7961
# t => 7962
# t => 7963
# t => 7964
# t => 7965
# t => 7966
# t => 7967
# t => 7968
# t => 7969
# t => 7970
# t => 7971
# t => 7972
# t => 7973
# t => 7974
# t => 7975
# t => 7976
# t => 7977
# t => 7978
# t => 7979
# t => 7980
# t => 7981
# t => 7982
# t => 7983
# t => 7984
# t => 7985
# t => 7986
# t => 7987
# t => 7988
# t => 7989
# t => 7990
# t => 7991
# t => 7992
# t => 7993
# t => 7994
# t => 7995
# t => 7996
# t => 7997
# t => 7998
# t => 7999
# t => 8000
# t => 8001
# t => 8002
# t => 8003
# t => 8004
# t => 8005
# t => 8006
# t => 8007
# t => 8008
# t => 8009
# t => 8010
# t => 8011
# t => 8012
# t => 8013
# t => 8014
# t => 8015
# t => 8016
# t => 8017
# t => 8018
# t => 8019
# t => 8020
# t => 8021
# t => 8022
# t => 8023
# t => 8024
# t => 8025
# t => 8026
# t => 8027
# t => 8028
# t => 8029
# t => 8030
# t => 8031
# t => 8032
# t => 8033
# t => 8034
# t => 8035
# t => 8036
# t => 8037
# t => 8038
# t => 8039
# t => 8040
# t => 8041
# t => 8042
# t => 8043
# t => 8044
# t => 8045
# t => 8046
# t => 8047
# t => 8048
# t => 8049
# t => 8050
# t => 8051
# t => 8052
# t => 8053
# t => 8054
# t => 8055
# t => 8056
# t => 8057
# t => 8058
# t => 8059
# t => 8060
# t => 8061
# t => 8062
# t => 8063
# t => 8064
# ['轨迹1' '轨迹2' '轨迹3' '轨迹4' '轨迹5' '轨迹6' '轨迹7' '轨迹8' '轨迹9' '轨迹10' '轨迹11'
#  '轨迹12' '轨迹13' '轨迹14' '轨迹15' '轨迹16' '轨迹17' '轨迹18' '轨迹19' '轨迹20' '轨迹21'
#  '轨迹22' '轨迹23' '轨迹24' '轨迹25' '轨迹26' '轨迹27' '轨迹序号' '轨迹35']
# t => 8065
# t => 8066
# t => 8067
# t => 8068
# t => 8069
# t => 8070
# t => 8071
# t => 8072
# t => 8073
# t => 8074
# t => 8075
# t => 8076
# t => 8077
# t => 8078
# t => 8079
# t => 8080
# t => 8081
# t => 8082
# t => 8083
# t => 8084
# t => 8085
# t => 8086
# t => 8087
# t => 8088
# t => 8089
# t => 8090
# t => 8091
# t => 8092
# t => 8093
# Done with translation

# %%
translations
# Out:
# {'女': 'Female',
#  '男': 'male',
#  '性别': 'gender',
#  '有': 'Have',
#  '未知': '未知',
#  '武汉（湖北）接触史': 'Wuhan (Hubei) Contact History',
#  '无': 'no',
#  ' 泸县牛滩镇': 'Niutan Town, Lu County',
#  '成都市新都区': 'Xindu District, Chengdu',
#  '顺庆区延安路海润滨江小区': "Hairun Binjiang Community, Yan'an Road, Shunqing District",
#  '叙州区南岸街道中山生态园小区': 'Zhongshan Ecological Park Community, Nanan Street, Xuzhou District',
#  '攀枝花市东区': 'East District of Panzhihua City',
#  '西昌': 'Xichang',
#  '锦江区': 'Jinjiang District',
#  '道孚县': 'Daofu County',
#  '遂宁市蓬溪县鸣凤镇青杠村': 'Qinggan Village, Mingfeng Town, Pengxi County, Suining City',
#  '成都市锦江区': 'Jinjiang District, Chengdu',
#  '成都市金堂县': 'Jintang County, Chengdu',
#  '成都市温江区': 'Wenjiang District, Chengdu',
#  '成都市天府新区': 'Tianfu New District, Chengdu',
#  '成都市武侯区': 'Wuhou District, Chengdu',
#  '成都市金牛区': 'Jinniu District of Chengdu',
#  '巴中市温江区': 'Wenjiang District, Bazhong City',
#  '上海': 'Shanghai',
#  '巴州区永泰花园东街7栋': 'Building 7, Yongtai Garden East Street, Bazhou District',
#  '岩峰镇凤阳村': 'Fengyang Village, Yanfeng Town',
#  '三板镇福城村': 'Fucheng Village, Sanban Town',
#  '绵竹市玉泉镇': 'Yuquan Town, Mianzhu City',
#  '湖北武汉': 'Wuhan, Hubei',
#  '双加镇': 'Shuangjia Zhen',
#  '隆昌市胡家镇': 'Hujia Town, Longchang City',
#  '泸县': 'Lu County',
#  '内江市东兴区翡翠国际': 'Emerald International, Dongxing District, Neijiang City',
#  '阆中市老观镇方山场': 'Fangshanchang, Laoguan Town, Langzhong City',
#  '岳池县罗渡镇兴盛小区': 'Xingsheng Community, Luodu Town, Yuechi County',
#  '岳池县石垭镇石普大道10号光明小区': 'Guangming Community, No. 10 Shipu Avenue, Shiya Town, Yuechi County',
#  '江阳区通滩镇': 'Tongtan Town, Jiangyang District',
#  '高坪区长乐镇': 'Changle Town, Gaoping District',
#  '开江县淙城街道办后街': 'Back Street of Congcheng Street Office, Kaijiang County',
#  '开江县淙城街道办嘉阳天宇2号楼': 'Building 2, Jiayang Tianyu, Congcheng Sub-district Office, Kaijiang County',
#  '安徽省马鞍山市雨山区万家兰苑12栋': "Building 12, Wanjialan Garden, Yushan District, Ma'anshan City, Anhui Province",
#  '湖北宜昌': 'Hubei Yichang',
#  '武汉': 'Wuhan',
#  '双加镇安置小区': 'Shuangjia Town Resettlement Community',
#  '恩阳区玉山镇街道': 'Street of Yushan Town, Enyang District',
#  '射洪广兴镇新场村': 'Xinchang Village, Guangxing Town, Shehong',
#  '南部县大河镇': 'Dahe Town, Nannan County',
#  '三台县潼川银座': 'Tongchuan Ginza, Santai County',
#  '开江县梅家乡大堰塘村': 'Dayantang Village, Meijia Township, Kaijiang County',
#  '开江县新安社区街道办玉龙苑8单元': "Unit 8, Yulongyuan, Xin'an Community Subdistrict Office, Kaijiang County",
#  '德阳市旌阳区': 'Jingyang District, Deyang City',
#  '凉山甘洛县': 'Ganluo County of Liangshan',
#  '凉山盐源': 'Liangshan Salt Source',
#  '射洪市广兴镇': 'Guangxing Town, Shehong City',
#  '武胜县鸣钟乡铁石坳村': "Tieshi'ao Village, Mingzhong Township, Wusheng County",
#  '巴州区云台街林业局家属院3栋': 'Building 3, Family House of Yuntai Street Forestry Bureau, Bazhou District',
#  '金堂县': 'Jintang County',
#  '龙泉驿区': 'Longquanyi District',
#  '河南驻马店': 'Zhumadian, Henan',
#  '天府新区': 'Tianfu New District',
#  '贵州省遵义市仁怀市茅台镇': 'Maotai Town, Renhuai City, Zunyi City, Guizhou Province',
#  '广安区南苑小区4栋': "Building 4, Nanyuan Community, Guang'an District",
#  '龙马潭区石洞街道': 'Shidong Street, Longmatan District',
#  '龙马潭区双加镇': 'Shuangjia Town, Longmatan District',
#  '江阳区泰安街道': "Tai'an Street, Jiangyang District",
#  '南充市顺庆区潆华路悠山丽景小区': 'Youjing Lijing Community, Huahua Road, Shunqing District, Nanchong City',
#  '湖北随州市': 'Suizhou City, Hubei Province',
#  '珙县': 'Gong County',
#  '重庆九龙坡区': 'Jiulongpo District, Chongqing',
#  '高新区': 'High-tech Zone',
#  '四川绵阳': 'Sichuan Mianyang',
#  '金牛区': 'Jinniu District',
#  '武侯区': 'Wuhou District',
#  '湖北黄冈': 'Hubei Huanggang',
#  '四川南': 'Sichuan South',
#  '新都区': 'Xindu District',
#  '简阳市': 'Jianyang',
#  '南充市顺庆区中城街道': 'Zhongcheng Street, Shunqing District, Nanchong City',
#  '渠县宝城镇新农村3栋-2单元4-4': 'Qu County Baocheng New Rural 3 Building-2 Unit 4-4',
#  '东城街道金地丽都小区': 'Jindi Lidu District, Dongcheng Street',
#  '仪陇县永山庙村': 'Yongshan Temple Village, Yilong County',
#  '广安区中桥街道': "Zhongqiao Jiedao, Guang'an District",
#  '广安区龙台镇': "Longtai Town, Guang'an District",
#  '仪陇县保平镇': 'Baoping Town, Yilong County',
#  ' 眉山市东坡区': 'Dongpo District, Meishan City',
#  ' 眉山市青神县': 'Qingshen County, Meishan City',
#  '湖北省鄂州市': 'Ezhou City, Hubei Province',
#  '营山县': 'Yingshan County',
#  '甘孜州道孚县': 'Daofu County, Ganzi Prefecture',
#  '内江市市中区城东街道': 'Chengdong Street, Shizhong District, Neijiang City',
#  '内江市威远县新店镇': 'Xindian Town, Weiyuan County, Neijiang City',
#  '成都': 'Chengdu',
#  '德阳市旌阳区黄许镇': 'Huangxu Town, Jingyang District, Deyang City',
#  '德阳市绵竹市广济镇': 'Guangji Town, Mianzhu City, Deyang City',
#  '湖北省监利县': 'Jianli County, Hubei Province',
#  '广汉市雒城镇': 'Luocheng Town, Guanghan City',
#  '德阳广汉雒城镇': 'Deyang Guanghan Luocheng Town',
#  '四川蓬安': "Peng'an, Sichuan",
#  '常住地': 'Permanent residence',
#  '东风街道瑞泰心里城4栋': 'Building 4, Ruitai Xinli City, Dongfeng Street',
#  '颍上县慎城镇': 'Shencheng Town, Yingshang County',
#  '霍邱县周集镇': 'Zhouji Town, Huoqiu County',
#  '和县历阳镇清佛村': 'Qingfo Village, Liyang Town, He County',
#  '安徽省广德市': 'Guangde City, Anhui Province',
#  '合肥市蜀山区': 'Shushan District, Hefei',
#  '合肥市新站区': 'Xinzhan District, Hefei',
#  '蚌埠市怀远县荆山镇健康小区5栋': 'Building 5, Health Community, Jingshan Town, Huaiyuan County, Bengbu City',
#  '蚌埠市蚌山区黄庄街道丰泽园小区6栋': 'Building 6, Fengzeyuan Community, Huangzhuang Street, Bengshan District, Bengbu City',
#  '蚌埠市禹会区张公山街道张公山二村': 'Zhanggongshan Second Village, Zhanggongshan Street, Yuhui District, Bengbu City',
#  '颍上县八里河镇': 'Balihe Town, Yingshang County',
#  '河北省衡水市故城县': 'Gucheng County, Hengshui City, Hebei Province',
#  '涡阳县': 'Guoyang County',
#  '合肥市庐阳区': 'Luyang District, Hefei',
#  '蚌埠市经开区湖滨社区天湖国际C区4栋': 'Building 4, Tianhu International Area C, Hubin Community, Economic Development Zone, Bengbu City',
#  '蚌埠市经开区长淮卫镇卫东村': 'Weidong Village, Changhuaiwei Town, Economic Development Zone, Bengbu City',
#  '阜南县新村镇': 'Xincun Town, Funan County',
#  '临泉县鲖城镇': 'Tortoise Town, Linquan County',
#  '城关镇富康村康洼树庄': 'Kangwa Shuzhuang, Fukang Village, Chengguan Town',
#  '利辛县城北镇建设路南': 'South Jianshe Road, Chengbei Town, Lixin County',
#  '利辛县城关镇': 'Chengguan Town, Lixin County',
#  '城关镇': 'Chengguan Town',
#  '蒙城县楚村镇常兴社区': 'Changxing Community, Chucun Town, Mengcheng County',
#  ' 利辛县': 'Lixin County',
#  '宿州埇桥': 'Suzhou Yongqiao',
#  '宿州砀山': 'Suzhou Dangshan',
#  '颍州区三塔集镇': 'Santa Pagoda Market Town, Yingzhou District',
#  '东至县昭潭镇龙潭村': 'Longtan Village, Zhaotan Town, Dongzhi County',
#  '蚌埠市经开区湖滨社区兰庭书苑1栋': 'Building 1, Lanting Book Garden, Hubin Community, Economic Development Zone, Bengbu City',
#  '户籍地址': 'Residence address',
#  '蚌埠市淮上区梅桥镇淝南村': 'Bannan Village, Meiqiao Town, Huaishang District, Bengbu City',
#  '蚌埠市禹会区纬四街道天地人花园1栋': 'Building 1, Tiandiren Garden, Weisi Street, Yuhui District, Bengbu City',
#  '蚌埠市经开区龙湖街道迎宾山庄C区14栋': 'Building 14, District C, Yingbin Villa, Longhu Street, Economic Development Zone, Bengbu City',
#  '蚌埠市龙子湖区东升街道': 'Dongsheng Street, Longzihu District, Bengbu City',
#  '蚌埠市龙子湖区东升街道长淮路淮建一村10栋': 'Building 10, Huaijian First Village, Changhuai Road, Dongsheng Street, Longzihu District, Bengbu City',
#  '合肥市包河区': 'Baohe District, Hefei',
#  '金寨县汤家汇镇': 'Tangjiahui Town, Jinzhai County',
#  '金寨县关庙乡': 'Guanmiao Township, Jinzhai County',
#  '宿州市泗县': 'Si County, Suzhou City',
#  '宿州市埇桥区': 'Yongqiao District, Suzhou City',
#  '蚌埠市高新区绿地世纪城社区伊顿公馆5栋': 'Building 5, Eaton Mansion, Greenland Century City Community, High-tech Zone, Bengbu City',
#  '蚌埠市禹会区张公山街道丰原小区3栋': 'Building 3, Fengyuan Community, Zhanggongshan Street, Yuhui District, Bengbu City',
#  '蚌埠市禹会区钓鱼台街道车苑小区67栋': 'Building 67, Cheyuan Community, Diaoyutai Street, Yuhui District, Bengbu City',
#  '蚌埠市龙子湖区解放街道东方之星小区2栋': 'Building 2, Dongfangzhixing Community, Jiefang Street, Longzihu District, Bengbu City',
#  '临泉县': 'Linquan County',
#  '颍上县江口镇': 'Jiangkou Town, Yingshang County',
#  '颍东区袁寨镇': 'Yuanzhai Town, Yingdong District',
#  '阜阳市经济技术开发区京九路街道': 'Jingjiu Road Street, Economic and Technological Development Zone, Fuyang City',
#  '铜陵市义安区钟鸣镇九榔村': "Jiulang Village, Zhongming Town, Yi'an District, Tongling City",
#  '铜陵市义安区胥坝': "Xuba, Yi'an District, Tongling City",
#  '怀宁': 'Huaining',
#  ' 望江': 'Wangjiang',
#  '相山区东街道': 'East Street of Xiangshan District',
#  '谯城区薛阁街道上善名郡': 'Shanming County, Xuege Street, Qiaocheng District',
#  '利辛县胡集镇程刘村': 'Chengliu Village, Huji Town, Lixin County',
#  '宿州泗县': 'Suzhou County',
#  '铜陵市枞阳县钱铺镇将军村': 'Jiangjun Village, Qianpu Town, Zongyang County, Tongling City',
#  '宣州区': 'Xuanzhou District',
#  '经开区': 'Economic Development Zone',
#  '蚌埠市蚌山区黄庄街道丰泽园小区4栋': 'Building 4, Fengzeyuan Community, Huangzhuang Street, Bengshan District, Bengbu City',
#  '蚌埠市龙子湖区东升街道华阳淮畔小区7栋': 'Building 7, Huayang Huaipan Community, Dongsheng Street, Longzihu District, Bengbu City',
#  '蚌埠市禹会区张公山街道张公山六村': 'Six Villages of Zhanggongshan, Zhanggongshan Street, Yuhui District, Bengbu City',
#  '蚌埠市高新区科苑社区嘉和豪庭1栋': 'Building 1, Jiahe Haoting, Keyuan Community, High-tech Zone, Bengbu City',
#  '临泉县城关街道': 'Chengguan Street, Linquan County',
#  '合肥市瑶海区': 'Yaohai District, Hefei City',
#  '利辛县城关镇闫郢村': 'Yan Ying Village, Chengguan Town, Lixin County',
#  '武汉市': 'Wuhan',
#  '凤凰山经济开发区小集村': 'Xiaoji Village, Fenghuangshan Economic Development Zone',
#  '濉溪县孙疃镇刘圩村': 'Liuxu Village, Suntuan Town, Suixi County',
#  '相山区曲阳街道': 'Quyang Street, Xiangshan District',
#  '淮北': 'Huaibei',
#  '湖北省仙桃市': 'Xiantao City, Hubei Province',
#  '，雨山区泰和天成': ', Taihe Tiancheng, Yushan District',
#  ' 雨山区阳光城': 'Sunshine City in Yushan District',
#  '武汉市武昌区': 'Wuchang District, Wuhan',
#  '武汉市江岸区': "Jiang'an District, Wuhan",
#  '阜南县柴集镇': 'Chaiji Town, Funan County',
#  '武汉市汉口区': 'Hankou District, Wuhan',
#  ' 雨山区银河湾': 'Yinhe Bay in Yushan District',
#  '湖南省湘潭市雨湖区': 'Yuhu District, Xiangtan City, Hunan Province',
#  '广东': 'Guangdong',
#  '武汉市江汉区': 'Jianghan District, Wuhan',
#  '武汉市洪山区': 'Hongshan District, Wuhan',
#  '湖北省洪山县': 'Hongshan County, Hubei Province',
#  '烟台龙口市': 'Yantai Longkou City',
#  '任城区长沟镇前陈村': 'Qianchen Village, Changgou Town, Rencheng District',
#  '武城县鲁权屯镇李贤屯村': 'Lixiantun Village, Luquantun Town, Wucheng County',
#  '淄川区松龄街道办事处安居小区': 'Anju Community, Songling Street Office, Zichuan District',
#  '山东省济宁市任城区任兴家园': 'Renxing Homeland, Rencheng District, Jining City, Shandong Province',
#  '东港区秦楼街道山海天杨庄子村': 'Yangzhuangzi Village, Shanhaitian, Qinlou Street, Donggang District',
#  '市南区四川路': 'Sichuan Road, Shinan District',
#  '滕州市荆河街道问天广场': 'Wentian Square, Jinghe Street, Tengzhou City',
#  '高新区新城街道北苑社区': 'Beiyuan Community, Xincheng Street, High-tech Zone',
#  '任城区唐口街道大流店村': 'Daliudian Village, Tangkou Street, Rencheng District',
#  '山东省济宁市任城区李营街道任兴家园': 'Renxing Homestead, Liying Street, Rencheng District, Jining City, Shandong Province',
#  '武城县武城镇西岳觉寺村': 'Xiyuejue Temple Village, Wucheng Town, Wucheng County',
#  '柏林镇柏林村': 'Berlin Village Berlin Town',
#  '坊子区黄旗堡街道花坞村': 'Huawu Village, Huangqibao Street, Fangzi District',
#  '诸城市百尺河镇百尺河村': 'Baichihe Village, Baichihe Town, Zhucheng City',
#  '山东省济宁市任城区唐口镇大流店村': 'Dalidian Village, Tangkou Town, Rencheng District, Jining City, Shandong Province',
#  '山东省济宁市任城区任兴路任兴家园': 'Renxing Road, Renxing Road, Rencheng District, Jining City, Shandong Province',
#  '山东省济宁市任城区洸河街道舜泰园小区': 'Shuntaiyuan Community, Luhe Street, Rencheng District, Jining City, Shandong Province',
#  '平邑县柏林镇柏林村': 'Berlin Village, Berlin Town, Pingyi County',
#  '无棣县海丰街道付家村': 'Fujia Village, Haifeng Street, Wudi County',
#  '博山区域城镇颜山国际': 'Yanshan International',
#  '淄川区龙泉镇龙四村': 'Longsi Village, Longquan Town, Zichuan District',
#  '历下区姚家街道窑头小区': 'Yaotou Community, Yaojia Street, Lixia District',
#  '张店区湖田街道保安小区': 'Baodian District, Hutian Street, Zhangdian District',
#  '烟台市高新区银海熙岸小区': "Yinhai Xi'an Community, High-tech Zone, Yantai",
#  '芝罘区黄务街道香槟小镇': 'Champagne Town, Huangwu Street, Zhifu District',
#  '济宁市任城区济阳街道太白国际小区': 'Taibai International Community, Jiyang Street, Rencheng District, Jining City',
#  '文登区龙山街道三里河路附近': 'Near Sanlihe Road, Longshan Street, Wendeng District',
#  '郯城县郯城街道龙域中央小区': 'Longyu Central Community, Tancheng Street, Tancheng County',
#  '阳谷县侨润街道县工商局家属院': 'Family House of the Industrial and Commercial Bureau of Qiaorun Sub-district, Yanggu County',
#  '郓城县陈坡乡龚屯村': 'Gongtun Village, Chenpo Township, Yuncheng County',
#  '黄岛区长江西路157号凤凰国际小区': 'Phoenix International Community, 157 West Changjiang Road, Huangdao District',
#  '龙洞街道锦屏家园': 'Jinping Home in Longdong Street',
#  '历下区甸新东路甸新佳园': 'Dianxinjiayuan, Dianxin East Road, Lixia District',
#  '博山区域城镇颜山国际小区': 'Yanshan International Community of Boshan District Town',
#  '山亭区千水星家具店': 'Qiantingxing Furniture Store in Shanting District',
#  '山亭区府前路太清湖小区': 'Taiqing Lake Community, Fuqian Road, Shanting District',
#  '牟平区文化街道新华新村': 'Xinhua New Village, Culture Street, Muping District',
#  '海阳市嵩山街9号楼': 'Building 9, Songshan Street, Haiyang City',
#  '奎文区玉清街江山帝景小区': 'Jiangshan Dijing Community, Yuqing Street, Kuiwen District',
#  '曲阜市华沁苑1期': 'Qufu City Huaqinyuan Phase 1',
#  '济宁市任城区太白国际小区': 'Taibai International Community, Rencheng District, Jining City',
#  '岱岳区粥店街道御驾新苑A区': 'District A, Yujia Xinyuan, Conge Street, Daiyue District',
#  '家居高新区良庄镇茅茨西村': 'Maozxi Village, Liangzhuang Town, High-tech Zone',
#  '高新区北集坡街道安居幸福里小区': 'Anju Xingli Community, Beijipo Street, High-tech Zone',
#  '泰山区泰前街道华新山水居': 'Huaxin Shanshuiju, Taiqian Street, Taishan District',
#  ' 家居高新区良庄镇茅茨西村': 'Maozxi Village, Liangzhuang Town, High-tech Zone',
#  '岱岳区范镇东岔河村富兴家园': 'Fuxing Homestead, Dongchahe Village, Fan Town, Daiyue District',
#  '威海市临港区苘山镇和谐苑小区': 'Harmony Garden Community, Fushan Town, Lingang District, Weihai City',
#  '乳山市海阳所镇海韵观海苑小区': 'Haiyunguan Haiyuan Community, Haiyangsuo Town, Rushan City',
#  '兰山区柳青街道润园小区': 'Runyuan Community, Liuqing Street, Lanshan District',
#  '莒南县坪上镇坪上一村': 'Pingshangyi Village, Pingshang Town, Junan County',
#  '东昌府区蒋官屯街道前铺村': 'Qianpu Village, Jiangguantun Street, Dongchangfu District',
#  '阳谷县侨润街道东润紫金苑': 'Dongrun Zijin Garden, Qiaorun Street, Yanggu County',
#  '牡丹区曹州路南华小区': 'Nanhua Community, Caozhou Road, Mudan District',
#  '红河镇东皋营村': 'Donggaoying Village, Honghe Town',
#  '历下区甸新东路甸柳家园': 'Dianliujiayuan, Dianxin East Road, Lixia District',
#  '历下区姚家街道万科城': 'Vanke City, Yaojia Street, Lixia District',
#  '黄岛区嘉陵江东路258号华裕黄金海岸': 'Huayu Gold Coast, No. 258 Jialingjiang East Road, Huangdao District',
#  '招远市罗峰办事处石门宋家村': 'Songjia Village, Shimen, Luofeng Office, Zhaoyuan City',
#  '山东省青岛市青岛市莱西市前疃村': 'Qiantuan Village, Laixi City, Qingdao City, Shandong Province',
#  '山东省青岛市市北陵县路': 'Beiling County Road, Qingdao City, Shandong Province',
#  '山东省青岛市李沧区虎山花园D区': 'District D, Hushan Garden, Licang District, Qingdao City, Shandong Province',
#  '莱西市翡翠城西区': 'West District of Jade City, Lacey City',
#  '阳谷县侨润办事处工商局家属院': 'Family Hospital of Yanggu County Overseas Chinese Affairs Office',
#  '新泰市羊流镇王家林村': 'Wangjialin Village, Yangliu Town, Xintai City',
#  '山东省泰安市泰山区上高街道凤凰小区': "Fenghuang District, Shanggao Street, Taishan District, Tai'an City, Shandong Province",
#  '武城县城区宏图学府': 'Hongtu Academy in Wucheng County',
#  '威海市环翠区琅声园小区': 'Langshengyuan Community, Huancui District, Weihai City',
#  '烟台市招远市石门宋家村': 'Songjia Village, Shimen, Zhaoyuan City, Yantai City',
#  '临沂市兰山区市水利局家属院': 'Family House of Water Conservancy Bureau of Lanshan District, Linyi City',
#  '临沂市兰山区五大道住宅区': 'Residential District of Five Avenues, Lanshan District, Linyi City',
#  ' 烟台高新区银海熙岸小区': "Yinhai Xi'an Community, Yantai High-tech Zone",
#  '枣庄市台儿庄区涧头集镇谢庄村': 'Xiezhuang Village, Jiantou Town, Taierzhuang District, Zaozhuang City',
#  '经区富安花园小区': "Fu'an Garden Community, Jingqu",
#  '东昌府区柳园街道唐庄回迁小区': 'Tangzhuang Huiqian Community, Liuyuan Street, Dongchangfu District',
#  '东昌府区柳园街道育新街7号': 'No.7 Yuxin Street, Liuyuan Street, Dongchangfu District',
#  '东昌府区古楼办事处望湖小区': 'Wanghu District, Gulou Office, Dongchangfu District',
#  '东昌府区古楼办事处回民小区': 'Huimin Community, Gulou Office, Dongchangfu District',
#  '经济开发区': 'economic development Zone',
#  '奎文区人': 'Kuiwen people',
#  '泰山区邱家店镇府前花园2号楼': 'Building 2, Fuqian Garden, Qiujiadian Town, Taishan District',
#  '泰山区财源街道粮食局宿舍1号楼': 'Building 1, Dormitory of Grain Bureau, Caiyuan Street, Taishan District',
#  '徂徕镇南黄崖村': 'South Huangya Village, Xuli Town',
#  '武汉市洪山区东湖花园': 'East Lake Garden, Hongshan District, Wuhan',
#  '东沙河镇党村': 'Dangcun Village, Dongshahe Town',
#  '红河镇张家楼村': 'Zhangjialou Village, Honghe Town',
#  '招远市罗峰办事处石门大宋家村10号': 'No. 10, Damenjia Village, Shimen, Luofeng Office, Zhaoyuan City',
#  '市北区南昌路48号正商红枫谷': 'Zhengfeng Red Maple Valley, No. 48 Nanchang Road, Shibei District',
#  '东昌府区': 'Dongchangfu District',
#  '平阴县榆山街道龙山小区': 'Longshan Community, Yushan Street, Pingyin County',
#  '历下区利农庄23号': 'No.23 Ligongzhuang, Lixia District',
#  '天桥区泺口街道河畔景苑': 'Riverside Jingyuan, Luokou Street, Tianqiao District',
#  '莱阳市万第镇旺屋庄村': 'Wangwuzhuang Village, Wandi Town, Laiyang City',
#  '历城区全福街道办事处锦绣澜湾小区': 'Jinxiu Lanwan Community, Quanfu Sub-district Office, Licheng District',
#  '肥城市大封矿宿舍18号楼': 'Building 18 of Feicheng Dafeng Mining Dormitory',
#  '宁阳县文庙街道锦绣城1号楼': 'Building 1, Jinxiu City, Wenmiao Street, Ningyang County',
#  '泰山区泮河大街老儿童医院宿舍': "Dormitory of Old Children's Hospital on Panhe Street, Taishan District",
#  '长清区崮云湖乐天小区': 'Lotte Community, Guyun Lake, Changqing District',
#  '泰山区擂鼓石花园10号楼': 'Building 10, Leigu Stone Garden, Taishan District',
#  '天桥区泺口街道河畔景苑社区': 'Riverside Jingyuan Community, Luokou Street, Tianqiao District',
#  '市中区七贤街道中海国际社区': 'Zhonghai International Community, Qixian Street, Shizhong District',
#  '历下区趵突泉小区一区': 'District 1, Baotuquan Community, Lixia District',
#  '东平县银山镇东茂王村': 'Dongmaowang Village, Yinshan Town, Dongping County',
#  '东平县银山镇昆山村': 'Kunshan Village, Yinshan Town, Dongping County',
#  '新泰市青云街道大洼村': 'Dawa Village, Qingyun Street, Xintai City',
#  '泰安高新区北集坡街道安居幸福里小区': "Anju Xingli Community, Beijipo Street, Tai'an High-tech Zone",
#  '新泰市幸福里小区对过原山东省电缆厂宿舍': 'Xintai City Xinglili Community passed through the former dormitory of Shandong Cable Factory',
#  '峄城区濠江花园4号楼': 'Building 4, Haojiang Garden, Yicheng District',
#  '河西街道德馨筑家小区': 'Dexin Zhujia Community, Hexi Street',
#  '临沂': 'Linyi',
#  '芝罘区': 'Zhifu District',
#  '莱山区': 'Laishan District',
#  '青岛市李沧区伟东幸福城二期': 'Phase II of Weidong Happy City, Licang District, Qingdao',
#  '晋城市城区书院街1261号古矿东区39号楼': 'Building 39, Gujing East District, No. 1261 Shuyuan Street, Jincheng District',
#  '朔州市朔城区北旺庄街道福煤小区': 'Fumei Community, Beiwangzhuang Street, Shuocheng District, Shuozhou City',
#  '古矿东区': 'Ancient Mine East',
#  '平遥县柳根花园': 'Liugen Garden in Pingyao County',
#  '尖草坪区南寨兴安社区64号楼': "Building 64, Xing'an Community, Nanzhai District, Jiancaoping District",
#  '迎泽区迎泽街道牛站巷迎泽苑8号楼': 'Building 8, Yingzeyuan, Niuzhan Alley, Yingze Street, Yingze District',
#  '迎泽区桥东街道东方红小区': 'Dongfanghong Community, Qiaodong Street, Yingze District',
#  '五台县茹村乡陡咀村': 'Douzui Village, Rucun Township, Wutai County',
#  '太原市迎泽区迎泽街道牛站巷迎泽苑': 'Yingzeyuan, Niuzhan Alley, Yingze Street, Yingze District, Taiyuan City',
#  '朔州市朔城区神头一电厂': 'Shentou No.1 Power Plant in Shuocheng District, Shuozhou City',
#  '朔州市朔城区神头二厂': 'Shuozhou Shuocheng Shentou No.2 Factory',
#  ' 平陆县圣人涧镇崔家坡': 'Cuijiapo, Sage River Town, Pinglu County',
#  '清徐县清源镇迎宪村苹果园小区': 'Apple Orchard Community, Yingxian Village, Qingyuan Town, Qingxu County',
#  '太原市尖草坪区南寨街办16号楼': 'Building 16, Nanzhai Street Office, Jiancaoping District, Taiyuan City',
#  '太原市杏花岭区胜利街晋安3号院': 'Jinan No. 3 Courtyard, Shengli Street, Xinghualing District, Taiyuan City',
#  '平遥县杜家庄乡苏家堡村': 'Sujiabao Village, Dujiazhuang Township, Pingyao County',
#  '平遥县宁固镇北侯村': 'Beihou Village, Ninggu Town, Pingyao County',
#  '平遥县香乐乡香乐村': 'Xiangle Village, Xiangle Township, Pingyao County',
#  '平遥县宁固镇左家堡': 'Zuojiabao, Ninggu Town, Pingyao County',
#  '尖草坪区汇丰街道兴华北小区': 'Xinghua North Community, Huifeng Street, Jiancaoping District',
#  '沁水县郑庄镇中乡村': 'Middle Village in Zhengzhuang Town, Qinshui County',
#  '临汾市吉县荣辰佳苑': 'Rongchen Jiayuan, Ji County, Linfen City',
#  '平陆县虞国一号小区': 'Pinglu County Yuguo No.1 Community',
#  '圣人涧镇盘南村': 'Pannan Village, Sage River Town',
#  '柴家乡北原村': 'Shibaie Kitahara Village',
#  '怀仁市': 'Huairen',
#  '阳城县水村商业园B区': 'District B, Shuicun Business Park, Yangcheng County',
#  '北石店镇锦泰嘉园小区': 'Jintai Jiayuan Community, Beishidian Town',
#  '泽州县北义城镇北义城村红星三巷07号': 'No. 07, Red Star Third Lane, Beiyicheng Village, Beiyi Town, Zezhou County',
#  '长子县': 'Changzi County',
#  '北京市前门西大街41号': 'No. 41, Qianmen West Street, Beijing',
#  '睢宁县睢城镇锦绣华庭': 'The splendid palace in Suicheng, Suining County',
#  '睢宁县睢城镇东方花园': 'Oriental Garden, Suincheng Town, Suining County',
#  '睢宁县睢城镇': 'Suincheng Town, Suining County',
#  '睢宁县桃园镇桃园村': 'Taoyuan Village, Taoyuan Town, Suining County',
#  '睢宁县岚山镇土山村': 'Tushan Village, Lanshan Town, Suining County',
#  '睢宁县欧洲城': 'European Town of Suining County',
#  '安徽宿州市': 'Suzhou City, Anhui',
#  '睢宁县东北小区': 'Northeast District of Suining County',
#  '睢宁县睢城镇睢城街道红旗小区': 'Hongqi Community, Sucheng Street, Sucheng Township, Suining County',
#  '睢宁县睢城镇龙城': 'Longcheng, Suicheng Town, Suining County',
#  '丰县华山镇邢桥村': 'Xingqiao Village, Huashan Town, Feng County',
#  '睢宁县康馨花园小区': 'Kangxin Garden Community of Suining County',
#  '睢宁县幸福家园小区': 'Suingjiayuan Community of Suining County',
#  '淮安': 'Huaian',
#  '宿迁经开区': 'Suqian Economic Development Zone',
#  '睢宁县睢城镇星河湾': 'Xinghe Bay, Suicheng Town, Suining County',
#  '睢宁县邱集镇大主村': 'Dazhu Village, Qiuji Town, Suining County',
#  '湖北孝感': 'Hubei Xiaogan',
#  '南京市建邺区': 'Jianye District, Nanjing',
#  '南京市溧水区': 'Lishui District, Nanjing',
#  '南京市栖霞区': 'Qixia District, Nanjing',
#  '南京市江宁区': 'Jiangning District, Nanjing',
#  '宜兴市宜城街道阳光花苑': 'Sunshine Garden, Yicheng Street, Yixing City',
#  '上海浦东新区': 'Shanghai Pudong New Area',
#  '云龙区骆驼山街道': 'Yuntuoshan Street, Yunlong District',
#  '浙江省绍兴': 'Shaoxing, Zhejiang Province',
#  '睢宁县': 'Suining County',
#  '通州区金新街道夏四店花苑': 'Xiasidian Garden, Jinxin Street, Tongzhou District',
#  '苏州张家港市杨舍镇东莱新村': 'Donglai New Village, Yangshe Town, Zhangjiagang City, Suzhou',
#  '苏州吴江区平望镇': 'Pingwang Town, Wujiang District, Suzhou',
#  '常熟市虞山街道五星新村2区': 'District 2, Wuxing New Village, Yushan Street, Changshu City',
#  '睢宁县高作镇高南村': 'Gaonan Village, Gaozuo Town, Suining County',
#  '睢宁县胡集村': 'Huji Village, Suining County',
#  '江苏南京': 'Nanjing, Jiangsu',
#  ' 湖北': 'Hubei',
#  '苏州吴中区木渎镇': 'Mudu Town, Wuzhong District, Suzhou',
#  '湖北': 'Hubei',
#  '润州区': 'Runzhou District',
#  '湖北省武汉市武昌区': 'Wuchang District, Wuhan City, Hubei Province',
#  '海门市滨江街道': 'Binjiang Street, Haimen City',
#  '海门市三厂镇龙江花园': 'Longjiang Garden, Sanchang Town, Haimen City',
#  '苏州工业园区莲花新村5区': 'District 5, Lianhuaxin Village, Suzhou Industrial Park',
#  '苏州常熟市鸭潭头小区': 'Suzhou Yatantou Community, Changshu City',
#  '苏州吴中区南': 'South of Wuzhong District, Suzhou',
#  '苏州工业园区': 'Suzhou Industrial Park',
#  '：大桥镇': ': Bridge Town',
#  '苏州工业园区东港二村': 'Donggang Second Village, Suzhou Industrial Park',
#  '徐州市睢宁县天华小区': 'Tianhua Community, Suining County, Xuzhou City',
#  '徐州市云龙区美的翰城，': 'The beautiful Hancheng in Yunlong District of Xuzhou City,',
#  '徐州市邳州市': 'Pizhou City, Xuzhou City',
#  '睢宁县睢城街道帝壹城': 'Emperor One City, Sucheng Street, Suining County',
#  '苏州市吴江区平望镇': 'Pingwang Town, Wujiang District, Suzhou',
#  '苏州市高新区': 'Suzhou High-tech Zone',
#  '苏州昆山市': 'Kunshan City, Suzhou',
#  '苏州吴江区': 'Suzhou Wujiang District',
#  '苏州太仓市': 'Suzhou Taicang City',
#  '徐州市沛县': 'Peixian County, Xuzhou City',
#  '湖北武汉市': 'Wuhan City, Hubei',
#  '常州市武进区湖塘镇': 'Hutang Town, Wujin District, Changzhou',
#  '常州市天宁区郑陆镇': 'Zhenglu Town, Tianning District, Changzhou City',
#  '常州市天宁区': 'Tianning District, Changzhou City',
#  '徐州市贾汪区': 'Jiawang District, Xuzhou City',
#  '苏州吴中区': 'Suzhou Wuzhong District',
#  '苏州相城区': 'Suzhou Xiangcheng District',
#  '苏州姑苏区': 'Suzhou Gusu District',
#  '广州市': 'Guangzhou City',
#  ' 沛县': 'Peixian',
#  '沛县': 'Peixian',
#  '邳州': 'Pizhou',
#  '苏州常熟市': 'Suzhou Changshu',
#  '内黄县楚旺镇': 'Chuwang Town, Neihuang County',
#  '滑县白道口镇': 'Baidaokou Town, Huaxian County',
#  '内黄县亳城乡': 'Bocheng Township, Neihuang County',
#  '安阳县辛村镇': 'Xincun Town, Anyang County',
#  '内黄县亳城': 'Bocheng, Neihuang County',
#  '东城区半截河街道办事处祥瑞小区': 'Xiangrui District, Banjiehe Sub-district Office, Dongcheng District',
#  '义乌': 'Yiwu',
#  '建安区陈曹乡伍连村': "Wulian Village, Chencao Township, Jian'an District",
#  '襄城县城关镇': 'Chengguan Town, Xiangcheng County',
#  '东城区': 'Dongcheng Area',
#  '隆胜华庭小区': '隆胜华庭小区',
#  '召陵区召陵镇茨张村': 'Cizhang Village, Zhaoling Town, Zhaoling District',
#  '太康县老冢镇': 'Laozuka Town, Taikang County',
#  '郸城县': 'Dancheng County',
#  '沈丘县': 'Shenqiu County',
#  '商水县': 'Shangshui County',
#  '柘城安平镇张店': 'Zhangdian, Anping Town, Zhecheng',
#  '富贵华庭小区': 'Fugui Huating Community',
#  '睢阳区文化街道振华南苑小区': 'Zhenhua Nanyuan Community, Wenhua Street, Suiyang District',
#  '柘城县岗王镇天门': 'Tianmen, Gangwang Town, Zhecheng County',
#  '夏邑县城关镇': 'Chengguan Town, Xiayi County',
#  '夏邑县郭店镇金庄村': 'Jinzhuang Village, Guodian Town, Xiayi County',
#  '夏邑县罗庄镇': 'Luozhuang Town, Xiayi County',
#  '武汉市江夏区藏龙大道银河湾': 'Yinhe Bay, Canglong Avenue, Jiangxia District, Wuhan',
#  '河南商丘梁园区': 'Shangqiuliang Park, Henan',
#  '商丘市东风街道豫立首府1号楼': 'Building 1, Yuli Capital, Dongfeng Street, Shangqiu City',
#  '湖北荆州': 'Jingzhou, Hubei',
#  '中原': 'Central Plains',
#  '鑫苑': '鑫苑',
#  '焦作市': '焦作市',
#  '南湾风景管理区南湾街道茶韵路': 'Chayun Road, Nanwan Street, Nanwan Scenic Resort',
#  ' 潢川县定城街道草湖路北苑': 'Beiyuan, Caohu Road, Dingcheng Street, Huangchuan County',
#  ' 息县项店镇街村': ' 息县项店镇街村',
#  '罗山县庙仙乡吴乡村': '罗山县庙仙乡吴乡村',
#  '瀍河区': '瀍河区',
#  '恒大名都': 'Evergrande',
#  '罗山县定远乡北洼村': 'Beiwa Village, Dingyuan Township, Luoshan County',
#  '金水区丰庆路': 'Fengqing Road, Jinshui District',
#  '瀍河区龙源花园': 'Longyuan Garden, Yinghe District',
#  '西工区金梨苑小区': 'Jinliyuan Community, Xigong District',
#  '滨河新村': '滨河新村',
#  '三全路': 'Sanquan Road',
#  '航海东路': '航海东路',
#  '西湖区三墩镇西城年华': '西湖区三墩镇西城年华',
#  '嘉善县天凝镇新联村4组': '嘉善县天凝镇新联村4组',
#  '下城区': '下城区',
#  '江北区文教街道双东路小区': '江北区文教街道双东路小区',
#  '文教街道翠柏西巷': '文教街道翠柏西巷',
#  '余姚市兰江街道伊顿国际': '余姚市兰江街道伊顿国际',
#  '萧山区': 'Xiaoshan Strict',
#  '乐清市': '乐清市',
#  '鹿城区': '鹿城区',
#  '永嘉县': 'Yongjia County',
#  '海口市琼山区': 'Qiongshan District, Haikou City',
#  '琼中县阳江': '琼中县阳江',
#  '浙江杭州': 'Hangzhou, Zhejiang',
#  '黑龙江': '黑龙江',
#  '湖北襄阳': '湖北襄阳',
#  '龙江牡丹江市': 'Longjiang Mudanjiang City',
#  '昌江县': '昌江县',
#  '新疆乌鲁木齐': 'Urumqi, Xinjiang',
#  '河南洛阳': 'LuoYang HeNan',
#  '黑龙江哈尔滨': '黑龙江哈尔滨',
#  '河南郑州': 'Zhengzhou, Henan',
#  '海口市美兰区': 'Meilan District, Haikou City',
#  '儋州市': 'Danzhou',
#  '湖北松滋': 'Songzi, Hubei',
#  '重庆市': 'Chongqing',
#  '海口市美兰区海府街道白坡里': 'Baipoli, Haifu Street, Meilan District, Haikou City',
#  '儋州市那大镇合罗农场': 'Danluo Dahe Heluo Farm',
#  '澄迈县华侨农场': '澄迈县华侨农场',
#  '海口市琼山区红旗镇': '海口市琼山区红旗镇',
#  '海口市龙华区大同二里': '海口市龙华区大同二里',
#  '昌江县昌化镇昌城村': '昌江县昌化镇昌城村',
#  '黑龙江鹤岗市': '黑龙江鹤岗市',
#  '海口市龙华区城西镇椰海昌茂城邦小区': '海口市龙华区城西镇椰海昌茂城邦小区',
#  '上海市': '上海市',
#  '海口市琼山区新大洲大道321号2楼': '海口市琼山区新大洲大道321号2楼',
#  '湖北十堰市': '湖北十堰市',
#  '湖南长沙市': '湖南长沙市',
#  '保亭县保城镇芙蓉小区': '保亭县保城镇芙蓉小区',
#  '海南乐东县': '海南乐东县',
#  '海南省三亚市天涯区椰风巷': '海南省三亚市天涯区椰风巷',
#  '江苏': 'Jiangsu',
#  '黑龙江哈尔滨市': '黑龙江哈尔滨市',
#  '海口市琼山区石塔村': '海口市琼山区石塔村',
#  '海口市琼山区凤翔街道江畔人家小区': 'Jiangpan Renjia Community, Fengxiang Street, Qiongshan District, Haikou City',
#  '海口市琼山区大园里147号': '海口市琼山区大园里147号',
#  '新疆昌吉州': '新疆昌吉州',
#  '三亚市吉阳区南新农场': '三亚市吉阳区南新农场',
#  '海口市琼山区凤翔东路江畔人家小区': '海口市琼山区凤翔东路江畔人家小区',
#  '湖南衡阳市': '湖南衡阳市',
#  '湖北广水市': '湖北广水市',
#  '昌江县石碌镇': '昌江县石碌镇',
#  '湖北荆门市': '湖北荆门市',
#  '海南省儋州市': '海南省儋州市',
#  '海南省海口市琼山区': 'Qiongshan District, Haikou City, Hainan Province',
#  '湖北孝感市': '湖北孝感市',
#  '江西高安市': '江西高安市',
#  '涟源市伏口镇柏树村': '涟源市伏口镇柏树村',
#  '江市渣渡镇银溪村': '江市渣渡镇银溪村',
#  '武陵区长庚街道西苑新村': '武陵区长庚街道西苑新村',
#  '云溪区云溪街道双花村': '云溪区云溪街道双花村',
#  '临澧县四新岗镇': '临澧县四新岗镇',
#  '岳阳楼区枫桥湖街道青螺小区': '岳阳楼区枫桥湖街道青螺小区',
#  '君山区柳林洲街道双元村': '君山区柳林洲街道双元村',
#  '安乡县深柳镇书院洲社区': '安乡县深柳镇书院洲社区',
#  '安乡县黄山头镇马坡湖村': '安乡县黄山头镇马坡湖村',
#  '武陵区': '武陵区',
#  '汉寿县酉港镇': '汉寿县酉港镇',
#  '武陵区府坪街道': '武陵区府坪街道',
#  ' 鼎城区黄土店镇': ' 鼎城区黄土店镇',
#  '澧县澧阳镇': '澧县澧阳镇',
#  '湘潭县': '湘潭县',
#  '荷塘区': '荷塘区',
#  '澧县小渡口镇': '澧县小渡口镇',
#  '澧县梦溪镇': '澧县梦溪镇',
#  '湖北省公安县': '湖北省公安县',
#  '韶山市': '韶山市',
#  ' 津市市毛里湖镇': ' 津市市毛里湖镇',
#  '武陵区长庚街道': '武陵区长庚街道',
#  '安乡县安凝乡': '安乡县安凝乡',
#  '澧县复兴镇': '澧县复兴镇',
#  ' 武陵区永安街道楠竹山': ' 武陵区永安街道楠竹山',
#  '汉寿县太子庙': '汉寿县太子庙',
#  '桃源县': '桃源县',
#  '武陵区南坪街道': '武陵区南坪街道',
#  '武汉归潭': '武汉归潭',
#  '澧县盐井镇': '澧县盐井镇',
#  '津市市三洲驿街道': '津市市三洲驿街道',
#  '鼎城区十美堂镇同富村': '鼎城区十美堂镇同富村',
#  '石门县二都街道': '石门县二都街道',
#  '安乡县大鲸港镇': '安乡县大鲸港镇',
#  '武陵区芷兰街道': '武陵区芷兰街道',
#  '澧县澧阳街道': '澧县澧阳街道',
#  '贵阳市云岩区水东社区': '贵阳市云岩区水东社区',
#  '汇川区泗渡镇泗渡居': '汇川区泗渡镇泗渡居',
#  '贵阳市清镇市站街镇林歹村青山组': '贵阳市清镇市站街镇林歹村青山组',
#  '真自治县玉溪镇未来国际小区': '真自治县玉溪镇未来国际小区',
#  '毕节市纳雍县乐治镇史家街村': '毕节市纳雍县乐治镇史家街村',
#  '遵义市汇川区泗渡镇泗渡居': '遵义市汇川区泗渡镇泗渡居',
#  '贵阳市南明区解放路356号': '贵阳市南明区解放路356号',
#  '贵阳市花溪区青岩镇北街村': '贵阳市花溪区青岩镇北街村',
#  '南明区花果园T2区': '南明区花果园T2区',
#  '花溪区瑞华社区万科大都会': '花溪区瑞华社区万科大都会',
#  '遵义市汇川区董公寺镇建国社区代家坝': '遵义市汇川区董公寺镇建国社区代家坝',
#  '遵义市汇川区上海路龙华山水小区': '遵义市汇川区上海路龙华山水小区',
#  '长顺县长寨街道威远社区新坝村平寨': '长顺县长寨街道威远社区新坝村平寨',
#  '贵定县锦江华府二期1号楼': '贵定县锦江华府二期1号楼',
#  '凯里市凯棠镇南江村': '凯里市凯棠镇南江村',
#  '六盘水市钟山区凤凰社区': '六盘水市钟山区凤凰社区',
#  '黔东南州天柱县渡马乡岩门村': '黔东南州天柱县渡马乡岩门村',
#  '湖北来安': '湖北来安',
#  '黔西县素朴镇百花村': '黔西县素朴镇百花村',
#  '赫章县妈姑镇九股村': '赫章县妈姑镇九股村',
#  ' 锦屏县彦洞乡救民村': ' 锦屏县彦洞乡救民村',
#  '万州区分水镇黄泥凼村': '万州区分水镇黄泥凼村',
#  '万州区牌楼街道清堰坡': '万州区牌楼街道清堰坡',
#  '万州区周家坝街道天龙路': '万州区周家坝街道天龙路',
#  '江北区观音桥': '江北区观音桥',
#  '江北区石马河': '江北区石马河',
#  '潼南区桂林街道龙潭社区': '潼南区桂林街道龙潭社区',
#  '长寿区龙河镇九龙村': '长寿区龙河镇九龙村',
#  '重庆市江北区': '重庆市江北区',
#  '綦江区文龙街道普惠尚城名都': '綦江区文龙街道普惠尚城名都',
#  '綦江区': 'Qijiang District',
#  '复街道诗仙东路78号': '复街道诗仙东路78号',
#  '西部新区飞洋世纪城1栋': '西部新区飞洋世纪城1栋',
#  '重庆市江北区观音桥街道嘉陵三村23号': '重庆市江北区观音桥街道嘉陵三村23号',
#  '重庆市綦江区三江街道雷园路126号': '重庆市綦江区三江街道雷园路126号',
#  '綦江区三江街道三江大桥桥头凤梧超市': '綦江区三江街道三江大桥桥头凤梧超市',
#  '綦江区文龙街道枫丹小区': '綦江区文龙街道枫丹小区',
#  '綦江区石角镇白云村': '綦江区石角镇白云村',
#  '綦江区石角镇欧家村': '綦江区石角镇欧家村',
#  '大河乡沈家街道': '大河乡沈家街道',
#  '万州区熊家镇古城大道': '万州区熊家镇古城大道',
#  '万州区百安坝街道百安大道': '万州区百安坝街道百安大道',
#  '万州区沙河街道青年路 ': '万州区沙河街道青年路 ',
#  '奉节县西部新区飞洋世纪城': '奉节县西部新区飞洋世纪城',
#  '万州区太白街道太白村': '万州区太白街道太白村',
#  '万州区高笋塘街道果园路西山公寓': '万州区高笋塘街道果园路西山公寓',
#  '万州区高笋塘街道': '万州区高笋塘街道',
#  '万州区太白街道': '万州区太白街道',
#  '万州区高笋塘街道财贸广场': '万州区高笋塘街道财贸广场',
#  '万州区牌楼街道金泉阳光花园小区': '万州区牌楼街道金泉阳光花园小区',
#  '万州区分水镇大兴村': '万州区分水镇大兴村',
#  '万州区牌楼街道御景江城 ': '万州区牌楼街道御景江城 ',
#  '万州区太白街道桂花路': '万州区太白街道桂花路',
#  '万州区牌楼街道': '万州区牌楼街道',
#  '万州区钟鼓楼街道山水国际小区': '万州区钟鼓楼街道山水国际小区',
#  '万州区高笋塘果园路西山公寓': '万州区高笋塘果园路西山公寓',
#  '南川区大观镇': '南川区大观镇',
#  '重庆市南岸区天文街道': '重庆市南岸区天文街道',
#  '重庆市南岸区长生桥镇富翔花园': '重庆市南岸区长生桥镇富翔花园',
#  '重庆市南岸区龙门浩街道天水伴山': '重庆市南岸区龙门浩街道天水伴山',
#  '金山街道': '金山街道',
#  '大竹林街道': '大竹林街道',
#  '福建福州': '福建福州',
#  '居天宫殿街道': '居天宫殿街道',
#  '巴南区南泉街道虎啸村': '巴南区南泉街道虎啸村',
#  '巴南区龙洲湾街道碧海湾小区': '巴南区龙洲湾街道碧海湾小区',
#  '巫山县骡坪镇玉水村': '巫山县骡坪镇玉水村',
#  '巫山县建平乡柳坪村': '巫山县建平乡柳坪村',
#  '巫山县高唐街道中央王府2号楼': '巫山县高唐街道中央王府2号楼',
#  '巫山县抱龙镇桃花街': '巫山县抱龙镇桃花街',
#  '巫山县高唐街道平湖路394号': '巫山县高唐街道平湖路394号',
#  '长寿区葛兰镇张家堡': '长寿区葛兰镇张家堡',
#  '涪陵区南沱镇红碑村': '涪陵区南沱镇红碑村',
#  '，马武镇均田村': '，马武镇均田村',
#  '文龙街道金兰街康瑞苑': '文龙街道金兰街康瑞苑',
#  '重庆市綦江区文龙街道优山美地': '重庆市綦江区文龙街道优山美地',
#  '重庆市綦江区石角镇欧家村': '重庆市綦江区石角镇欧家村',
#  '綦江区文龙街道德信小区': '綦江区文龙街道德信小区',
#  '文龙街道': '文龙街道',
#  '城口县坪坝镇': '城口县坪坝镇',
#  '城口县沿河乡红岩村': '城口县沿河乡红岩村',
#  '湖北省襄阳市': '湖北省襄阳市',
#  ' 彭水县岩东乡堰塘村': ' 彭水县岩东乡堰塘村',
#  '沙坪坝区陈家桥街道金科天': '沙坪坝区陈家桥街道金科天',
#  '，乡村基上清寺': '，乡村基上清寺',
#  '大足区邮亭镇金地阳光小区': '大足区邮亭镇金地阳光小区',
#  '邮亭镇新利村': '邮亭镇新利村',
#  '巴川街道白龙花园': '巴川街道白龙花园',
#  '，沙心村': '，沙心村',
#  '大庙镇长安街': '大庙镇长安街',
#  '中南路55号': '中南路55号',
#  '屏锦镇柏树村': '屏锦镇柏树村',
#  '梁山街道石马小区南': '梁山街道石马小区南',
#  '梁平区文化镇新中街30号': '梁平区文化镇新中街30号',
#  '万州区周家坝申明大道': '万州区周家坝申明大道',
#  '高笋塘街道白岩书院': '高笋塘街道白岩书院',
#  '万州区双河口街道富康花园': '万州区双河口街道富康花园',
#  '万州区天城镇天雄路': '万州区天城镇天雄路',
#  '万州区陈家坝街道江南大道': '万州区陈家坝街道江南大道',
#  '万州区钟鼓楼': '万州区钟鼓楼',
#  '万州区钟鼓楼街道': '万州区钟鼓楼街道',
#  '万州区长坪乡大树村': '万州区长坪乡大树村',
#  '万州区武陵镇禹安村': '万州区武陵镇禹安村',
#  '万州响水镇': '万州响水镇',
#  '万州区武陵镇': '万州区武陵镇',
#  '百安坝街道安庆路': '百安坝街道安庆路',
#  '万州百安坝街道上海大道': '万州百安坝街道上海大道',
#  '万州高笋塘街道春天花园小区': '万州高笋塘街道春天花园小区',
#  '万州区周家坝街道周家坝街道富康苑': '万州区周家坝街道周家坝街道富康苑',
#  '万州长滩镇羊渠街 ': '万州长滩镇羊渠街 ',
#  '万州区钟鼓楼街道清江上城': '万州区钟鼓楼街道清江上城',
#  '万州区江南新区': '万州区江南新区',
#  '万州区钟鼓楼街道桑树坪': '万州区钟鼓楼街道桑树坪',
#  '万州区钟鼓楼街道北山': '万州区钟鼓楼街道北山',
#  '万州区陈家坝街道南山绿庭26栋': 'Building 26, Nanshan Lvting, Chenjiaba Street, Wanzhou District',
#  '万州区后街太白街道后街金座小区': '万州区后街太白街道后街金座小区',
#  '万州区牌楼街道御景江城': '万州区牌楼街道御景江城',
#  '万州区太白街道滨湖花园小区': '万州区太白街道滨湖花园小区',
#  '万州区长坪乡弹子村': 'Danzi Village, Changping Township, Wanzhou District',
#  '万州区牌楼街道天然气公司宿舍小区': '万州区牌楼街道天然气公司宿舍小区',
#  '万州区熊家镇应村': '万州区熊家镇应村',
#  '万州区太白街道天仙湖': '万州区太白街道天仙湖',
#  '万州区铁峰乡箭楼村': '万州区铁峰乡箭楼村',
#  '万州区百安坝街道万川大道': '万州区百安坝街道万川大道',
#  '万州区甘宁镇围灯村': '万州区甘宁镇围灯村',
#  '万州区龙都街道汇景苑小区': 'Huijingyuan Community, Longdu Street, Wanzhou District',
#  '长滩镇白岩村': '长滩镇白岩村',
#  '钟鼓楼街道北滨': '钟鼓楼街道北滨',
#  '合川区涞滩镇双龙湖两塘村': '合川区涞滩镇双龙湖两塘村',
#  '合川区钱塘镇长安新村': '合川区钱塘镇长安新村',
#  '合川区钱塘镇会龙高石村': '合川区钱塘镇会龙高石村',
#  '合川区柏树街58号如家酒店': '合川区柏树街58号如家酒店',
#  '合川区燕窝镇梅娅村': '合川区燕窝镇梅娅村',
#  '合川区钱塘镇灰坝村': '合川区钱塘镇灰坝村',
#  '合川区柏树街如家酒店': '合川区柏树街如家酒店',
#  '潼南区梓潼街道': 'Tong Street, Tongnan District',
#  '丰都县兴龙镇春花山村': 'Chunhuashan Village, Xinglong Town, Fengdu County',
#  '丰都县三合街道': '丰都县三合街道',
#  '丰都县三合街道东升路': 'Dongsheng Road, Sanhe Street, Fengdu County',
#  '湖北省襄阳市襄城区': '湖北省襄阳市襄城区',
#  '丰都县': 'Fengdu County',
#  '忠县任家镇任家村': '忠县任家镇任家村',
#  '奉节县飞洋世纪城5栋': 'Building 5, Feiyang Century City, Fengjie County',
#  '居忠县三汇镇罗岭村': 'Luoling Village, Sanhui Town, Juzhong County',
#  '居忠县石宝镇神溪村': 'Shenxi Village, Shibao Town, Juzhong County',
#  '居忠县石宝镇大梁街9号': 'No. 9, Daliao Street, Shibao Town, Juzhong County',
#  '忠州街道香山公馆4号楼': 'Building 4, Xiangshan Mansion, Chungju Street',
#  '居忠县石宝镇咸隆村': '居忠县石宝镇咸隆村',
#  '忠县白公街道人民路277号': '忠县白公街道人民路277号',
#  '忠县': 'Zhongxian',
#  '石宝镇石宝街鼎都花园': 'Dingdu Garden, Shibao Street, Shibao Town',
#  '忠县拔山镇石联村': 'Shilian Village, Bashan Town, Zhongxian County',
#  '白公街道石马村': '白公街道石马村',
#  '石柱县西沱镇': 'Xituo Town, Shizhu County',
#  '石柱县万安街道': '石柱县万安街道',
#  '石柱县南宾街道': 'Nanbin Street, Shizhu County',
#  '广西': 'Guangxi',
#  '清升镇': '清升镇',
#  '浙江': '浙江',
#  '安徽': '安徽',
#  '河南': '河南',
#  '开州区丰乐街道': 'Fengle Street, Kaizhou District',
#  '开州区白鹤街道': 'Baihe Street, Kaizhou District',
#  '开州区赵家街道': 'Zhaojia Street, Kaizhou District',
#  '开州区文峰街道': 'Kaifeng District Wenfeng Street',
#  '开州区厚坝镇': '开州区厚坝镇',
#  '开州区铁桥镇': 'Tieqiao Town, Kaizhou District',
#  '开州区岳溪镇': 'Yuexi Town, Kaizhou District',
#  '开州区汉丰街道': 'Hanfeng Street, Kaizhou District',
#  '奉节县大树镇凤仙村': '奉节县大树镇凤仙村',
#  '奉节县夔门街道宝塔坪陈家包11栋': 'Building 11, Chenjiabao, Baotaping, Kuimen Street, Fengjie County',
#  '奉节县西部新区飞洋世纪城5栋': '奉节县西部新区飞洋世纪城5栋',
#  '奉节县永安街道金橙街58号': '奉节县永安街道金橙街58号',
#  '奉节县西部新区飞洋世纪城1栋': '奉节县西部新区飞洋世纪城1栋',
#  '牌楼街道金泉阳光花园小区': 'Jinquan Sunshine Garden Community, Pailou Street',
#  '重庆市万州区白羊镇三湾东路': '重庆市万州区白羊镇三湾东路',
#  '牌楼街道牌楼街道牌楼街道金泉阳光花园小区小区': '牌楼街道牌楼街道牌楼街道金泉阳光花园小区小区',
#  '钟鼓楼街道山水国际小区11号楼': '钟鼓楼街道山水国际小区11号楼',
#  '万州区长坪乡长坪社区': 'Changping Community, Changping Township, Wanzhou District',
#  '万州区长坪乡': 'Changping Township, Wanzhou District',
#  '重庆市綦江区普惠尚城名都': '重庆市綦江区普惠尚城名都',
#  '綦江区文龙街道阳光奥韵小区': 'Sunshine Aoyun Community, Wenlong Street, Qijiang District',
#  '綦江区古南街道南门路134号': 'No. 134 South Gate Road, Gunan Street, Qijiang District',
#  '江北区渝北三村': '江北区渝北三村',
#  '江北区健安路30号南桥寺聚慧雅苑小区': '江北区健安路30号南桥寺聚慧雅苑小区',
#  '江北区红土地100号': 'No. 100 Red Land, Jiangbei District',
#  '江北区五江路18号': 'No. 18 Wujiang Road, Jiangbei District',
#  '江北区国惠路15号农场国奥村': 'Guoao Village, Farm, 15 Guohui Road, Jiangbei District',
#  '江北区北滨一路363号招商江湾城': 'China Merchants Jiangwan City, No.363 Beibin 1st Road, Jiangbei District',
#  '江北区北城3路65号融景城丽苑小区': 'Liyuan Community, Rongjing City, No. 65, Beicheng 3 Road, Jiangbei District',
#  '江北区盘溪路266号南桥寺维丰南桥小区': 'Nanqiao Temple Weifeng Nanqiao District, No. 266 Panxi Road, Jiangbei District',
#  '江北区大石坝街道': '江北区大石坝街道',
#  '江北区海尔路鲁能星城小区': 'Luneng Star City Community, Haier Road, Jiangbei District',
#  '江北区中海北滨一号': 'No.1 Beihai, Zhonghai, Jiangbei District',
#  '江北区兴竹路鹏润蓝海C区': 'Area C, Pengrun Blue Ocean, Xingzhu Road, Jiangbei District',
#  '奉节县安坪镇下坝村': '奉节县安坪镇下坝村',
#  '安坪镇下坝村': '安坪镇下坝村',
#  '天城镇万河村': 'Wancheng Village, Tiancheng Town',
#  '万州区白羊镇三湾路': 'Sanwan Road, Baiyang Town, Wanzhou District',
#  '分水镇红豆村': '分水镇红豆村',
#  '万州区牌楼街道御景江城12号楼': 'Building 12, Yujingjiang City, Pailou Street, Wanzhou District',
#  '万州区棉花地外贸车队2栋': 'Building 2 of Cotton Land Foreign Trade Team in Wanzhou District',
#  '复兴路': 'Fuxing Road',
#  '万州区北滨大道二段天仙湖': 'Tianxian Lake, Section 2, Beibin Avenue, Wanzhou District',
#  '万州区白羊镇源河路': 'Yuanhe Road, Baiyang Town, Wanzhou District',
#  '长坪乡长坪社区': 'Changping Community, Changping Township',
#  '井口街道新升南溪园小区': '井口街道新升南溪园小区',
#  '渝北区龙塔街道': '渝北区龙塔街道',
#  '渝北区龙山街道': '渝北区龙山街道',
#  '渝北区龙溪街道': 'Longxi Street, Yubei District',
#  '渝北区双龙湖街道': 'Shuanglonghu Street, Yubei District',
#  '四川泸州': 'Sichuan Luzhou',
#  '渝北区回兴街道': 'Huixing Street, Yubei District',
#  '四川省': '四川省',
#  '病例公布省份': '病例公布省份',
#  '安徽省': 'Anhui Province',
#  '山东省': 'Shandong Province',
#  '山西省': 'Shanxi Province',
#  '江苏省': 'Jiangsu Province',
#  '河南省': '河南省',
#  '浙江省': 'Zhejiang Province',
#  '海南省': '海南省',
#  '湖南省': 'Hunan Province',
#  '贵州省': 'Guizhou Province',
#  '泸州市': 'Luzhou City',
#  '甘孜藏族自治州': 'Ganzi Tibetan Autonomous Prefecture',
#  '成都市': 'Chengdu',
#  '宜宾市': 'Yibin',
#  '攀枝花市': 'Panzhihua',
#  '凉山彝族自治州': 'Liangshan Yi Autonomous Prefecture',
#  '遂宁市': 'Suining',
#  '南充市': 'Nanchong',
#  '巴中市': '巴中市',
#  '达州市': 'Dazhou',
#  '广元市': 'Guangyuan',
#  '内江市': 'Neijiang',
#  '广安市': "Guang'an",
#  '眉山市': 'Meishan',
#  '绵阳市': 'Mianyang',
#  '资阳市': 'Ziyang',
#  '德阳市': 'Deyang',
#  '雅安市': "Ya'an city",
#  '西昌市': 'Xichang',
#  '病例公布城市': 'Case announcement city',
#  '阜阳市': 'Fuyang',
#  '六安市': "Lu'an",
#  '马鞍山市': 'Maanshan',
#  '合肥市': 'Hefei',
#  '广德市': 'Guangde City',
#  '蚌埠市': 'Bengbu',
#  '亳州市': 'Bozhou',
#  '淮南市': 'Huainan',
#  '宿州市': 'Suzhou',
#  '池州市': 'Chizhou',
#  '芜湖市': 'Wuhu',
#  '铜陵市': 'Tongling City',
#  '安庆市': 'Anqing',
#  '淮北市': 'Huaibei City',
#  '宣城市': '宣城市',
#  '济宁市': '济宁市',
#  '德州市': 'Dezhou',
#  '淄博市': 'Zibo',
#  '日照市': 'Rizhao',
#  '青岛市': 'Qingdao',
#  '枣庄市': 'Zaozhuang',
#  '潍坊市': 'Weifang',
#  '临沂市': 'Linyi City',
#  '滨州市': 'Binzhou',
#  '济南市': 'Jinan City',
#  '烟台市': 'Yantai',
#  '威海市': 'Weihai',
#  '聊城市': '聊城市',
#  '菏泽市': 'Heze',
#  '泰安市': "Tai'an",
#  '朔州市': 'Shuozhou',
#  '晋中市': 'Jinzhong',
#  '太原市': 'Taiyuan',
#  '忻州市': 'Xinzhou',
#  '大同市': 'Datong City',
#  '阳泉市': '阳泉市',
#  '晋城市': 'Jincheng',
#  '运城市': 'Yuncheng',
#  '长治市': 'Changzhi',
#  '徐州市': 'Xuzhou',
#  '常州市': 'Changzhou City',
#  '宿迁市': '宿迁市',
#  '南京市': 'Nanjing',
#  '盐城市': 'Yancheng',
#  '宜兴市': 'Yixing',
#  '海门市': 'Haimen',
#  '南通市': 'Nantong city',
#  '苏州市': 'Suzhou City',
#  '镇江市': '镇江市',
#  '扬州市': 'Yangzhou',
#  '安阳市': '安阳市',
#  '许昌市': '许昌市',
#  '三门峡市': 'Sanmenxia',
#  '新乡市': 'Xinxiang',
#  '洛阳市': 'Luoyang City',
#  '周口市': 'Zhoukou',
#  '商丘市': 'Shangqiu',
#  '郑州市': 'Zhengzhou City',
#  '信阳市': 'Xinyang',
#  '杭州市': 'Hangzhou',
#  '嘉兴市': '嘉兴市',
#  '宁波市': 'Ningbo City',
#  '台州市': 'Taizhou',
#  '温州市': 'Wenzhou city',
#  '三亚市': 'Sanya',
#  '海口市': '海口市',
#  '琼中黎族苗族自治县': 'Qiongzhong Li and Miao Autonomous County',
#  '陵水黎族自治县': 'Lingshui Li Autonomous County',
#  '澄迈县': 'Chengmai County',
#  '定安县': "Ding'an County",
#  '\xa0三亚市': 'Sanya',
#  '昌江黎族自治县': '昌江黎族自治县',
#  '乐东黎族自治县': 'Ledong Li Autonomous County',
#  '琼海市': 'Qionghai',
#  '文昌市': '文昌市',
#  '万宁市': 'Wanning',
#  '文昌市\t': 'Wenchang',
#  '琼山区': 'Qiongshan District',
#  '保亭黎族苗族自治县': 'Baoting Li and Miao Autonomous County',
#  '陵水县': '陵水县',
#  '株洲市': 'Zhuzhou City',
#  '常德市': 'Changde',
#  '岳阳市': '岳阳市',
#  '益阳市': 'Yiyang',
#  '湘潭市': 'Xiangtan',
#  '遵义市': 'Zunyi City',
#  '毕节市': 'Bijie',
#  '贵阳市': 'Guiyang City',
#  '铜仁市': 'Tongren',
#  '黔南布依族苗族自治州': 'Qiannan Buyi and Miao Autonomous Prefecture',
#  '黔西南布依族苗族自治州': 'Qianxi Southwest Buyi and Miao Autonomous Prefecture',
#  '安顺市': 'Anshun',
#  '万州区': '万州区',
#  '江北区': 'Jiangbei District',
#  '云阳县': '云阳县',
#  '璧山区': 'Bishan District',
#  '铜梁区': 'Tongliang District',
#  '荣昌区': '荣昌区',
#  '潼南区': 'Tongnan District',
#  '奉节县': 'Fengjie County',
#  '长寿区': '长寿区',
#  '大足区': 'Dazu District',
#  '永川区': 'Yongchuan District',
#  '南岸区': 'South Bank area',
#  '两江新区': 'Liangjiang New District',
#  '巴南区': 'Banan District',
#  '巫山县': 'Wushan County',
#  '九龙坡区': 'Jiulongpo District',
#  '涪陵区': 'Fuling District',
#  '城口县': '城口县',
#  '彭水县': 'Pengshui County',
#  '渝中区': '渝中区',
#  '梁平区': 'Liangping District',
#  '合川区': 'Hechuan District',
#  '石柱土家族自治县': 'Shizhu Tujia Autonomous County',
#  '江津区': 'Gotsu Ward',
#  '开州区': 'Kaizhou District',
#  '沙坪坝区': '沙坪坝区',
#  '秀山县': 'Xiushan County',
#  '渝北区': 'Yu Bei District',
#  '1月19日': 'January 19',
#  '1月23日': 'January 23',
#  '1月24日': 'January 24',
#  '2月19日': '2月19日',
#  '1月7日': 'January 7',
#  '1月22日': 'January 22',
#  '2月5日': 'February 5',
#  '2月6日': 'February 6',
#  '2月7日': '2月7日',
#  '1月12日至21日': 'January 12-21',
#  '1月25日': 'January 25',
#  '1月26日': 'January 26',
#  '1月27日': 'January 27',
#  '1月28日': 'January 28',
#  '2月11日': 'February 11',
#  '2月12日': '2月12日',
#  '2月13日': 'February 13',
#  '2月14日': '2月14日',
#  '2月15日': 'February 15',
#  '2月16日': 'February 16',
#  '2月18日': 'February 18',
#  '1月20日': 'January 20',
#  '1月28': '1月28',
#  '2月8日': 'February 8',
#  '2月9日': '2月9日',
#  '2月10日': 'February 10',
#  '2月17日': 'February 17',
#  '1月30日': '1月30日',
#  '2月1日': '2月1日',
#  '2月4日': 'February 4',
#  '1月31日': 'January 31',
#  '1月17日': 'January 17',
#  '1月21日': 'January 21',
#  '1月13日': 'January 13',
#  '2月3日': 'February 3',
#  '1月18日': '1月18日',
#  '1月29日': 'January 29',
#  '2月1日至4日': '2月1日至4日',
#  '2月2日': 'February 2',
#  '1月26': '1月26',
#  '1月23': 'Jan 23',
#  '1月26日晚': '1月26日晚',
#  '1月16日': '1月16日',
#  '1月11日': 'January 11',
#  '1月14日': '1月14日',
#  '1月10日': '1月10日',
#  '1月13': 'Jan 13',
#  '1月25': 'Jan 25',
#  '1月12日': 'January 12',
#  '早上10点': '早上10点',
#  '半小时': '半小时',
#  '1月15日': 'January 15',
#  '7点': "7 o'clock",
#  '9点': '9:00',
#  '晚上': 'at night',
#  '7点31': '7点31',
#  '1月18号': 'January 18',
#  '6时56分': '6:56',
#  '13时59分': '13:59',
#  '15时': '15时',
#  '时间': 'time',
#  '1月27-28日': '27-28 January',
#  '1月30日-31日': '1月30日-31日',
#  '1月26日-28日': 'January 26-28',
#  '1月14': 'Jan 14',
#  '1月4日': 'January 4',
#  '2019年11月底': 'End of November 2019',
#  '1月9日': '1月9日',
#  '1月8日': '1月8日',
#  '1月30': 'January 30',
#  '11月23日': 'November 23',
#  '1月3日': '1月3日',
#  '1月27': 'Jan 27',
#  '1月20日-23日': 'January 20-23',
#  '26日': '26th',
#  '1月6日': 'January 6',
#  '1月17': 'Jan 17',
#  '1月21': '1月21',
#  '1月24日-29日': '24-29 January',
#  '7时': '7时',
#  '17点07': '17:07',
#  '上午7-8时': '7-8 am',
#  '12时': "12 o'clock",
#  '下午18时': '下午18时',
#  '晚20时': '20pm',
#  '下午3点': '下午3点',
#  '8时21分': '8时21分',
#  '14时30分': '14时30分',
#  '1月22': 'Jan 22',
#  '1月24日-28日': '24-28 January',
#  '2月1日-2日': 'February 1-2',
#  '2月4日-5日': '2月4日-5日',
#  '1月25日-29日': 'January 25-29',
#  '1月23日-29日': 'January 23-29',
#  '1月31号': '1月31号',
#  '1月28日-31日': 'January 28-31',
#  '1月18日-20日': 'January 18-20',
#  '1月20日-21日': 'January 20-21',
#  '2月2日-6日': '2月2日-6日',
#  '1月23日-27日': 'January 23-27',
#  '1月26日-29日': 'January 26-29',
#  '1月11日-月17日': 'January 11-17',
#  '1月19日-30日': 'January 19-30',
#  ...}

# %%
# modify all the terms of the data frame by using the previously created dictionary
df_en.replace(translations, inplace = True)

# check translation
df_en.head()
# Out:
#    Age  Gender  ... Track Number Number Of Tracks
# 0   51  Female  ...          轨迹1                4
# 1   51  Female  ...          轨迹2                4
# 2   51  Female  ...      Track 3                4
# 3   51  Female  ...      Track 4                4
# 4   50    male  ...          轨迹1                2
#
# [5 rows x 12 columns]

# %%
from google.colab import files

df.to_csv('covid.csv')
files.download('covid.csv')

# %%
from google.colab import files

df_en.to_csv('covid-en-0.5.csv')
files.download('covid-en-0.5.csv')

# %% [markdown]
# ### Fixing translation bugs
#
# Most of the cells in our dataframe are translated by Google Translation API. But there are some cells which are not translated properly. What we can do at this point is finding unique elements and translating them manually through logic.

# %%
# fixing hubei contact translation

df_en['Hubei Contact'].unique()
# Out:
# array(['Have', '未知', 'Wuhan (Hubei) Contact History', 'no'], dtype=object)

# %%
df_en['Hubei Contact'].replace('未知', False, inplace=True)
df_en['Hubei Contact'].replace('Have', True, inplace=True)
df_en['Hubei Contact'].replace('Wuhan (Hubei) Contact History', True, inplace=True)
df_en['Hubei Contact'].replace('no', False, inplace=True)

# finally changing data type to boolean
df_en[["Hubei Contact"]] = df_en[["Hubei Contact"]].astype("bool")

df_en.dtypes
# Out:
# Age                            int64
# Gender                        object
# Hubei Contact                   bool
# Permanent Residence           object
# Case Announcement Province    object
# Case Announcement City        object
# Time                          object
# Route Location                object
# Event                         object
# Description                   object
# Track Number                  object
# Number Of Tracks               int64
# dtype: object

# %%
# fixing Case Announcement Province translation
df_en['Case Announcement Province'].unique()
# Out:
# array(['四川省', '病例公布省份', 'Anhui Province', 'Shandong Province',
#        'Shanxi Province', 'Jiangsu Province', '河南省', 'Zhejiang Province',
#        '海南省', 'Hunan Province', 'Guizhou Province', 'Chongqing'],
#       dtype=object)

# %%
df_en['Case Announcement Province'].replace({'四川省': 'Sichuan Province', '病例公布省份': 'Others', '河南省': 'Henan Province', '海南省': 'Hainan Province'}, inplace=True)

# %%
df_en['Case Announcement Province'].unique()
# Out:
# array(['Sichuan Province', 'Others', 'Anhui Province',
#        'Shandong Province', 'Shanxi Province', 'Jiangsu Province',
#        'Henan Province', 'Zhejiang Province', 'Hainan Province',
#        'Hunan Province', 'Guizhou Province', 'Chongqing'], dtype=object)

# %%
# fixing Gender translation
df_en['Gender'].unique()
# Out:
# array(['Female', 'male', 'gender'], dtype=object)

# %%
df_en['Gender'].replace({'Female': 'female', 'gender': 'others'}, inplace=True)
df_en['Gender'].unique()
# Out:
# array(['female', 'male', 'others'], dtype=object)

# %%
# fixing Case Announcement City
df_en['Case Announcement City'].unique()
# Out:
# array(['Luzhou City', 'Ganzi Tibetan Autonomous Prefecture', 'Chengdu',
#        'Yibin', 'Panzhihua', 'Liangshan Yi Autonomous Prefecture',
#        'Suining', 'Nanchong', '巴中市', 'Dazhou', 'Guangyuan', 'Neijiang',
#        "Guang'an", 'Meishan', 'Mianyang', 'Ziyang', 'Deyang',
#        "Ya'an city", 'Xichang', 'Case announcement city', 'Fuyang',
#        "Lu'an", 'Maanshan', 'Hefei', 'Guangde City', 'Bengbu', 'Bozhou',
#        'Huainan', 'Suzhou', 'Chizhou', 'Wuhu', 'Tongling City', 'Anqing',
#        'Huaibei City', '宣城市', '济宁市', 'Dezhou', 'Zibo', 'Rizhao',
#        'Qingdao', 'Zaozhuang', 'Weifang', 'Linyi City', 'Binzhou',
#        'Jinan City', 'Yantai', 'Weihai', '聊城市', 'Heze', "Tai'an",
#        'Shuozhou', 'Jinzhong', 'Taiyuan', 'Xinzhou', 'Datong City', '阳泉市',
#        'Jincheng', 'Yuncheng', 'Changzhi', 'Xuzhou', 'Changzhou City',
#        '宿迁市', 'Nanjing', 'Yancheng', 'Yixing', 'Haimen', 'Nantong city',
#        'Suzhou City', '镇江市', 'Yangzhou', '安阳市', '许昌市', 'Sanmenxia',
#        'Xinxiang', 'Luoyang City', 'Zhoukou', 'Shangqiu',
#        'Zhengzhou City', '焦作市', 'Xinyang', 'Hangzhou', '嘉兴市',
#        'Ningbo City', 'Taizhou', 'Wenzhou city', 'Sanya', '海口市',
#        'Danzhou', 'Qiongzhong Li and Miao Autonomous County',
#        'Lingshui Li Autonomous County', 'Chengmai County',
#        "Ding'an County", '昌江黎族自治县', 'Ledong Li Autonomous County',
#        'Qionghai', '文昌市', 'Wanning', 'Wenchang', 'Qiongshan District',
#        'Baoting Li and Miao Autonomous County', '陵水县', 'Zhuzhou City',
#        'Changde', '岳阳市', 'Yiyang', 'Xiangtan', 'Zunyi City', 'Bijie',
#        'Guiyang City', 'Tongren',
#        'Qiannan Buyi and Miao Autonomous Prefecture',
#        'Qianxi Southwest Buyi and Miao Autonomous Prefecture', 'Anshun',
#        '万州区', 'Jiangbei District', '云阳县', 'Bishan District',
#        'Tongliang District', 'Qijiang District', '荣昌区',
#        'Tongnan District', 'Fengjie County', '长寿区', 'Dazu District',
#        'Yongchuan District', 'South Bank area', 'Liangjiang New District',
#        'Banan District', 'Wushan County', 'Jiulongpo District',
#        'Fuling District', '城口县', 'Fengdu County', 'Pengshui County',
#        '渝中区', 'Liangping District', 'Hechuan District', 'Zhongxian',
#        'Shizhu Tujia Autonomous County', 'Gotsu Ward', 'Kaizhou District',
#        '沙坪坝区', 'Xiushan County', 'Yu Bei District'], dtype=object)

# %%
df_en['Case Announcement City'].replace(
    {
        '巴中市': 'Bazhong',
        'Case announcement city': 'Others',
        '宣城市': 'Xuancheng',
        '济宁市': 'Jining City',
        '聊城市': 'Liaocheng',
        '阳泉市': 'Yangquan City',
        '宿迁市': 'Suqian City',
        '镇江市': 'Zhenjiang',
        '安阳市': 'Anyang City',
        '许昌市': 'Xuchang City',
        '焦作市': 'Jiaozuo City',
        '嘉兴市': 'Jiaxing City',
        '海口市': 'Haikou',
        '昌江黎族自治县': 'Changjiang Li',
        '文昌市': 'Wenchang City',
        '陵水县': 'Lingshui County',
        '岳阳市': 'Yueyang City',
        '万州区': 'Wanzhou District',
        '云阳县': 'Yunyang County',
        '荣昌区': 'Rongchang District',
        '长寿区': 'Changshou District',
        '城口县': 'Chengkou County',
        '渝中区': 'Yuzhong District',
        '沙坪坝区': 'Shapingba District'
    }, 
inplace=True)

# %%
df_en['Case Announcement City'].unique()
# Out:
# array(['Luzhou City', 'Ganzi Tibetan Autonomous Prefecture', 'Chengdu',
#        'Yibin', 'Panzhihua', 'Liangshan Yi Autonomous Prefecture',
#        'Suining', 'Nanchong', 'Bazhong', 'Dazhou', 'Guangyuan',
#        'Neijiang', "Guang'an", 'Meishan', 'Mianyang', 'Ziyang', 'Deyang',
#        "Ya'an city", 'Xichang', 'Others', 'Fuyang', "Lu'an", 'Maanshan',
#        'Hefei', 'Guangde City', 'Bengbu', 'Bozhou', 'Huainan', 'Suzhou',
#        'Chizhou', 'Wuhu', 'Tongling City', 'Anqing', 'Huaibei City',
#        'Xuancheng', 'Jining City', 'Dezhou', 'Zibo', 'Rizhao', 'Qingdao',
#        'Zaozhuang', 'Weifang', 'Linyi City', 'Binzhou', 'Jinan City',
#        'Yantai', 'Weihai', 'Liaocheng', 'Heze', "Tai'an", 'Shuozhou',
#        'Jinzhong', 'Taiyuan', 'Xinzhou', 'Datong City', 'Yangquan City',
#        'Jincheng', 'Yuncheng', 'Changzhi', 'Xuzhou', 'Changzhou City',
#        'Suqian City', 'Nanjing', 'Yancheng', 'Yixing', 'Haimen',
#        'Nantong city', 'Suzhou City', 'Zhenjiang', 'Yangzhou',
#        'Anyang City', 'Xuchang City', 'Sanmenxia', 'Xinxiang',
#        'Luoyang City', 'Zhoukou', 'Shangqiu', 'Zhengzhou City',
#        'Jiaozuo City', 'Xinyang', 'Hangzhou', 'Jiaxing City',
#        'Ningbo City', 'Taizhou', 'Wenzhou city', 'Sanya', 'Haikou',
#        'Danzhou', 'Qiongzhong Li and Miao Autonomous County',
#        'Lingshui Li Autonomous County', 'Chengmai County',
#        "Ding'an County", 'Changjiang Li', 'Ledong Li Autonomous County',
#        'Qionghai', 'Wenchang City', 'Wanning', 'Wenchang',
#        'Qiongshan District', 'Baoting Li and Miao Autonomous County',
#        'Lingshui County', 'Zhuzhou City', 'Changde', 'Yueyang City',
#        'Yiyang', 'Xiangtan', 'Zunyi City', 'Bijie', 'Guiyang City',
#        'Tongren', 'Qiannan Buyi and Miao Autonomous Prefecture',
#        'Qianxi Southwest Buyi and Miao Autonomous Prefecture', 'Anshun',
#        'Wanzhou District', 'Jiangbei District', 'Yunyang County',
#        'Bishan District', 'Tongliang District', 'Qijiang District',
#        'Rongchang District', 'Tongnan District', 'Fengjie County',
#        'Changshou District', 'Dazu District', 'Yongchuan District',
#        'South Bank area', 'Liangjiang New District', 'Banan District',
#        'Wushan County', 'Jiulongpo District', 'Fuling District',
#        'Chengkou County', 'Fengdu County', 'Pengshui County',
#        'Yuzhong District', 'Liangping District', 'Hechuan District',
#        'Zhongxian', 'Shizhu Tujia Autonomous County', 'Gotsu Ward',
#        'Kaizhou District', 'Shapingba District', 'Xiushan County',
#        'Yu Bei District'], dtype=object)

# %%
# fixing track numbers translation
df_en['Track Number'].unique()
# Out:
# array(['轨迹1', '轨迹2', 'Track 3', 'Track 4', 'Track 5', 'Track 6', '轨迹7',
#        '轨迹8', '轨迹9', 'Track 10', 'Track 11', 'Track 12', '轨迹13',
#        'Track 14', 'Track 15', '轨迹16', 'Track 17', '轨迹18', '轨迹19', '轨迹20',
#        'Track 21', 'Track 22', '轨迹23', '轨迹24', 'Track 25', '轨迹26', '轨迹27',
#        'Track number', '轨迹35'], dtype=object)

# %%
df_en['Track Number'].replace({
    '轨迹1': 'Track 1',
    '轨迹2': 'Track 2',
    '轨迹7': 'Track 7',
    '轨迹8': 'Track 8',
    '轨迹9': 'Track 9',
    '轨迹13': 'Track 13',
    '轨迹16': 'Track 16',
    '轨迹18': 'Track 18',
    '轨迹19': 'Track 19',
    '轨迹20': 'Track 20',
    '轨迹23': 'Track 23',
    '轨迹24': 'Track 24',
    '轨迹26': 'Track 26',
    '轨迹27': 'Track 27',
    '轨迹35': 'Track 35',
    'Track number': 'Track Others',
}, inplace=True)
df_en['Track Number'].unique()
# Out:
# array(['Track 1', 'Track 2', 'Track 3', 'Track 4', 'Track 5', 'Track 6',
#        'Track 7', 'Track 8', 'Track 9', 'Track 10', 'Track 11',
#        'Track 12', 'Track 13', 'Track 14', 'Track 15', 'Track 16',
#        'Track 17', 'Track 18', 'Track 19', 'Track 20', 'Track 21',
#        'Track 22', 'Track 23', 'Track 24', 'Track 25', 'Track 26',
#        'Track 27', 'Track Others', 'Track 35'], dtype=object)

# %% [markdown]
# #### Download partially translated frame as CSV

# %%
from google.colab import files

df_en.to_csv('covid-en-0.8.csv')
files.download('covid-en-0.8.csv')

# %% [markdown]
# With this initial data wrangling and translations ends here. Next, we will be translating rest of the data which couldn't be translated due to huge number of amount will be translated through Googel Sheets tools.
#
# 😀😀😀
